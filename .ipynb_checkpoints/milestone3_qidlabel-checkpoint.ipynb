# %% [markdown]
# # The evolution of the presence of women’s voices in the media
# Team ALLG : Amaia Soubelet, Lilian Haemmerli, Lucie Castella, Gabriel Juri

# %%
###Importing all the useful librairies

import time
import json
import bz2
import pandas as pd
import numpy as np
import re
from pathlib import Path
import matplotlib.pyplot as plt
import pyarrow as pa
import pyarrow.parquet as pq
import glob

# %% [markdown]
# ### Handling data

# %%
###  IMPORTING DATA ###

# Define the path where the data is located

Path = "../quotes-2020.json.bz2" #goes out of the current folder

# %% [markdown]
# To decrease the running time, we uploaded and filtered the different year's data one by one on different computers. Here is how it was done for the year 2020. We just changed the path and the name of the output cvs file for the different years. At the end of this document, you can see those cvs files being loaded and the result of each year pictured in pie charts.

# %%
#Filtering functions

def find_proba(text):
    num = re.findall(r'-?\d+\.?\d*',text)
    return " ".join(num)

def filter_speakers(chunk_data):

    chunk_data['probas'] = chunk_data['probas'].astype('str')
    chunk_data['number'] = chunk_data['probas'].apply(lambda x: find_proba(x)) #extracts the probability of the given speaker to be correct
    filt_low = chunk_data.drop(chunk_data[chunk_data['number'] < '0.9'].index) #removes lines with low probabilities to have the right speaker (less than 90%)
    filt_prob = filt_low.drop(filt_low[filt_low['speaker'] == 'None'].index) #removes the lines with no speaker
    return filt_prob

# %% [markdown]
# The two functions above are used to filter the data. Every quote that does not have a speaker (the speaker is 'None') is removed. We also filtered the quotes depending on the probability that the given speaker is the right one. Every quote with a speaker probability of less than 0.9 was removed. Since our work is studying the gender of the speaker, we needed to be sure that the speakers linked to the quotations are the real speakers.

# %%
def process_chunk(chunk):
        print(f'Processing chunk with {len(chunk)} rows')
        print(chunk.columns)

with pd.read_json(Path, lines=True, compression='bz2', chunksize=1_000_000) as df_reader:
    dfs = []
    for chunk in df_reader:
        process_chunk(chunk)        
        filt_chunk = filter_speakers(chunk) #filters the lines we want to remove
        dfs.append(filt_chunk)
# Out:
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 244449 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')

# %%
chunk.head() #not filtered --> to check the difference
# Out:
#                    quoteID                                          quotation  \
# 5000000  2020-03-06-047752  People get killed in wildlife collisions, most...
# 5000001  2020-01-31-070691  People my age and older have to figure out how...
# 5000002  2020-03-26-047932  People now have time on their hands and they w...
# 5000003  2020-01-10-061824  People should not recourse to violent methods ...
# 5000004  2020-04-02-047663  People think it's novel that 80-year-olds are ...
#
#                  speaker                                               qids  \
# 5000000     Dave Marsden                                         [Q5240722]
# 5000001  Michelle Buteau                                        [Q54861496]
# 5000002        Gary Gray  [Q21228842, Q3758498, Q5525157, Q5525158, Q552...
# 5000003    Peter Machado                                         [Q1385539]
# 5000004    Candace Owens                                        [Q43302090]
#
#                        date  numOccurrences  \
# 5000000 2020-03-06 17:20:36               3
# 5000001 2020-01-31 17:47:00               2
# 5000002 2020-03-26 19:43:00               1
# 5000003 2020-01-10 03:04:23               1
# 5000004 2020-04-02 12:27:27               2
#
#                                                     probas  \
# 5000000   [['Dave Marsden', '0.6329'], ['None', '0.3671']]
# 5000001  [['Michelle Buteau', '0.8651'], ['None', '0.13...
# 5000002      [['Gary Gray', '0.8611'], ['None', '0.1389']]
# 5000003  [['Peter Machado', '0.9013'], ['None', '0.0987']]
# 5000004  [['Candace Owens', '0.7324'], ['Anthony Fauci'...
#
#                                                       urls phase  \
# 5000000  [http://www.washingtontimes.com/news/2020/mar/...     E
# 5000001  [https://www.nbcnews.com/news/nbcblk/michelle-...     E
# 5000002  [http://capenews.net/sandwich/news/business-is...     E
# 5000003     [https://www.newkerala.com/news/2020/4460.htm]     E
# 5000004  [https://www.news18.com/news/world/alarm-denia...     E
#
#                               number
# 5000000                0.6329 0.3671
# 5000001                0.8651 0.1349
# 5000002                0.8611 0.1389
# 5000003                0.9013 0.0987
# 5000004  0.7324 0.1735 0.0903 0.0038

# %%
filt_chunk.head() #filtered
# Out:
#                    quoteID                                          quotation  \
# 5000003  2020-01-10-061824  People should not recourse to violent methods ...
# 5000016  2020-03-18-052109     Please stay away... while crews assess damage,
# 5000022  2020-01-24-066016  possibility of a heart bypass cannot be ruled out
# 5000033  2020-02-15-035807  Previously, many things were given flexibility...
# 5000035  2020-04-15-045130  Pritzker using a coronavirus briefing to campa...
#
#                                      speaker  \
# 5000003                        Peter Machado
# 5000016                         Gary Herbert
# 5000022  Victoria , Crown Princess of Sweden
# 5000033                  Eddin Syazlee Shith
# 5000035                        Tim Schneider
#
#                                       qids                date  \
# 5000003                         [Q1385539] 2020-01-10 03:04:23
# 5000016                          [Q881188] 2020-03-18 08:48:00
# 5000022                          [Q156390] 2020-01-24 18:54:14
# 5000033                        [Q55584836] 2020-02-15 16:24:42
# 5000035  [Q18745477, Q19663584, Q28466557] 2020-04-15 00:00:00
#
#          numOccurrences                                             probas  \
# 5000003               1  [['Peter Machado', '0.9013'], ['None', '0.0987']]
# 5000016               1   [['Gary Herbert', '0.9404'], ['None', '0.0596']]
# 5000022               5  [['Victoria , Crown Princess of Sweden', '0.90...
# 5000033               1  [['Eddin Syazlee Shith', '0.9581'], ['None', '...
# 5000035               1  [['Tim Schneider', '0.9489'], ['None', '0.0511']]
#
#                                                       urls phase  \
# 5000003     [https://www.newkerala.com/news/2020/4460.htm]     E
# 5000016  [https://www.cityweekly.net/BuzzBlog/archives/...     E
# 5000022  [https://www.geo.tv/latest/268956-nawaz-sharif...     E
# 5000033   [http://bernama.com/general/news.php?id=1814213]     E
# 5000035  [http://dailyherald.com/news/20200415/pritzker...     E
#
#                 number
# 5000003  0.9013 0.0987
# 5000016  0.9404 0.0596
# 5000022  0.9058 0.0942
# 5000033  0.9581 0.0419
# 5000035  0.9489 0.0511

# %%
pd.concat(dfs)
# Out:
#                    quoteID                                          quotation  \
# 7        2020-01-17-000357  [ The delay ] will have an impact [ on Slough ...
# 8        2020-04-02-000239  [ The scheme ] treats addiction as an illness ...
# 9        2020-03-19-000276  [ These ] actions will allow households who ha...
# 16       2020-01-08-000594                   11 straight weeks of pre-season,
# 19       2020-02-21-000455  2019 was a landmark year for Fiverr as we comp...
# ...                    ...                                                ...
# 5244412  2020-03-24-093541  You can't get social distance in a submarine a...
# 5244424  2020-03-28-040445                              You Know I' m No Good
# 5244435  2020-02-02-058890  You understood the structure of our story and ...
# 5244437  2020-01-28-115305  You'd probably be able to do that every now an...
# 5244448  2020-02-24-080256  You've got to think that long term, it augurs ...
#
#                  speaker                                               qids  \
# 7           Dexter Smith                                         [Q5268447]
# 8        Barry Coppinger                                         [Q4864119]
# 9             Ben Carson                                          [Q816459]
# 16        Aphelele Fassi                                        [Q56255401]
# 19         Micha Kaufman                                        [Q26923564]
# ...                  ...                                                ...
# 5244412       Mark Esper                                        [Q33190271]
# 5244424    Amy Winehouse                                           [Q15897]
# 5244435     Bong Joon Ho                                          [Q495980]
# 5244437  Michael Maguire  [Q3856214, Q4274205, Q42887501, Q6832442, Q683...
# 5244448      John Colley                                        [Q18530304]
#
#                        date  numOccurrences  \
# 7       2020-01-17 13:03:00               1
# 8       2020-04-02 14:18:20               1
# 9       2020-03-19 19:14:00               1
# 16      2020-01-08 10:22:11               1
# 19      2020-02-21 13:00:00               1
# ...                     ...             ...
# 5244412 2020-03-24 22:32:54               1
# 5244424 2020-03-28 17:00:40               1
# 5244435 2020-02-02 08:27:01               4
# 5244437 2020-01-28 23:26:18               1
# 5244448 2020-02-24 04:30:00               3
#
#                                                     probas  \
# 7           [['Dexter Smith', '0.924'], ['None', '0.076']]
# 8        [['Barry Coppinger', '0.9017'], ['None', '0.09...
# 9           [['Ben Carson', '0.9227'], ['None', '0.0773']]
# 16       [['Aphelele Fassi', '0.9033'], ['None', '0.096...
# 19       [['Micha Kaufman', '0.9409'], ['None', '0.0591']]
# ...                                                    ...
# 5244412     [['Mark Esper', '0.9434'], ['None', '0.0566']]
# 5244424  [['Amy Winehouse', '0.9469'], ['None', '0.0477...
# 5244435  [['Bong Joon Ho', '0.9476'], ['None', '0.0454'...
# 5244437  [['Michael Maguire', '0.9191'], ['None', '0.08...
# 5244448      [['John Colley', '0.928'], ['None', '0.072']]
#
#                                                       urls phase  \
# 7        [http://www.sloughexpress.co.uk/gallery/slough...     E
# 8        [http://www.theweek.co.uk/106479/why-police-ar...     E
# 9        [https://mortgageorb.com/hud-fha-suspend-forec...     E
# 16       [https://www.sport24.co.za/Rugby/SuperRugby/sh...     E
# 19       [https://www.fool.com/investing/2020/02/21/why...     E
# ...                                                    ...   ...
# 5244412  [https://news.usni.org/2020/03/24/navy-adapts-...     E
# 5244424  [https://www.goldderby.com/article/2020/the-ma...     E
# 5244435  [https://www.prokerala.com/news/articles/a1003...     E
# 5244437  [http://www.nrl.com/news/2020/01/29/tigers-and...     E
# 5244448  [http://www.farmweekly.com.au/story/6646057/st...     E
#
#                                            number
# 7                                     0.924 0.076
# 8                                   0.9017 0.0983
# 9                                   0.9227 0.0773
# 16                                  0.9033 0.0967
# 19                                  0.9409 0.0591
# ...                                           ...
# 5244412                             0.9434 0.0566
# 5244424        0.9469 0.0477 0.0021 0.0019 0.0014
# 5244435  0.9476 0.0454 0.004 0.0015 8.0 -4 7.0 -4
# 5244437                             0.9191 0.0809
# 5244448                               0.928 0.072
#
# [701514 rows x 10 columns]

# %%
df = pd.concat(dfs)
df['qids'] = df['qids'].str[0]

# %% [markdown]
# ### Adding the .parquet database given

# %%
### Merging and importing parquet files into csv
from pathlib import Path

data_dir = Path('C:/data/speaker_attributes.parquet')
for i, parquet_path in enumerate(data_dir.glob('*.parquet')):
    df = pd.read_parquet(parquet_path)
    write_header = i == 0 # write header only on the 0th file
    write_mode = 'w' if i == 0 else 'a' # 'write' mode for 0th file, 'append' otherwise
    df.to_csv('featuresQID.csv', mode=write_mode, header=write_header)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-8370a49ee763> in <module>
#       4 data_dir = Path('C:/data/speaker_attributes.parquet')
#       5 for i, parquet_path in enumerate(data_dir.glob('*.parquet')):
# ----> 6     df = pd.read_parquet(parquet_path)
#       7     write_header = i == 0 # write header only on the 0th file
#       8     write_mode = 'w' if i == 0 else 'a' # 'write' mode for 0th file, 'append' otherwise
#
# ~\anaconda3\lib\site-packages\pandas\io\parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     498         storage_options=storage_options,
#     499         use_nullable_dtypes=use_nullable_dtypes,
# --> 500         **kwargs,
#     501     )
#
# ~\anaconda3\lib\site-packages\pandas\io\parquet.py in read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     238         try:
#     239             result = self.api.parquet.read_table(
# --> 240                 path_or_handle, columns=columns, **kwargs
#     241             ).to_pandas(**to_pandas_kwargs)
#     242             if manager == "array":
#
# ~\anaconda3\lib\site-packages\pyarrow\parquet.py in read_table(source, columns, use_threads, metadata, use_pandas_metadata, memory_map, read_dictionary, filesystem, filters, buffer_size, partitioning, use_legacy_dataset, ignore_prefixes)
#    1730
#    1731         return dataset.read(columns=columns, use_threads=use_threads,
# -> 1732                             use_pandas_metadata=use_pandas_metadata)
#    1733
#    1734     if ignore_prefixes is not None:
#
# ~\anaconda3\lib\site-packages\pyarrow\parquet.py in read(self, columns, use_threads, use_pandas_metadata)
#    1608         table = self._dataset.to_table(
#    1609             columns=columns, filter=self._filter_expression,
# -> 1610             use_threads=use_threads
#    1611         )
#    1612
#
# ~\anaconda3\lib\site-packages\pyarrow\_dataset.pyx in pyarrow._dataset.Dataset.to_table()
#
# ~\anaconda3\lib\site-packages\pyarrow\_dataset.pyx in pyarrow._dataset.Scanner.to_table()
#
# ~\anaconda3\lib\site-packages\pyarrow\error.pxi in pyarrow.lib.pyarrow_internal_check_status()
#
# ~\anaconda3\lib\site-packages\pyarrow\error.pxi in pyarrow.lib.check_status()
#
# OSError: NotImplemented: Support for codec 'snappy' not built

# %%
### Merging qotes and gender charateristic of each speaker 

featuresQID = pd.read_csv('C:/data/featuresQID.csv',low_memory=False)
featuresQID = featuresQID.rename(columns = {'id':'qids'})
dff = pd.merge(df,featuresQID[['qids','gender','ethnic_group','occupation','academic_degree','nationality','date_of_birth']],on='qids', how='left')

# %%
dff['ethnic_group'].value_counts()
# Out:
# ['Q49085']                 16576
# ['Q7325']                   4307
# ['Q974693']                 3210
# ['Q1282294' 'Q6889284']     2175
# ['Q7994501']                1422
#                            ...
# ['Q170284']                    1
# ['Q1053996']                   1
# ['Q3090691']                   1
# ['Q1996477']                   1
# ['Q3474201']                   1
# Name: ethnic_group, Length: 494, dtype: int64

# %%
dff['date_of_birth'].value_counts()
# Out:
# ['+1946-06-14T00:00:00Z']                            5046
# ['+2000-01-01T00:00:00Z']                            3475
# ['+2000-00-00T00:00:00Z']                            3141
# ['+1957-12-06T00:00:00Z']                            2331
# ['+1986-01-03T00:00:00Z']                            2326
#                                                      ...
# ['+1934-10-01T00:00:00Z']                               1
# ['+2003-07-13T00:00:00Z']                               1
# ['+1979-02-12T00:00:00Z']                               1
# ['+1919-02-16T00:00:00Z']                               1
# ['+1931-09-14T00:00:00Z' '+1931-10-17T00:00:00Z']       1
# Name: date_of_birth, Length: 27745, dtype: int64

# %%
dff['gender'].value_counts()
# Out:
# ['Q6581097']                         575817
# ['Q6581072']                         111093
# ['Q1052281']                            504
# ['Q48270']                              242
# ['Q18116794']                            88
# ['Q2449503']                             67
# ['Q6581097' 'Q179294']                   42
# ['Q48270' 'Q6581072']                    23
# ['Q1984232']                             21
# ['Q6581072' 'Q48270']                    18
# ['Q15145778']                            15
# ['Q6581097' 'Q189125']                   14
# ['Q15145779']                            10
# ['Q12964198']                             6
# ['Q1097630' 'Q48270']                     5
# ['Q27679766' 'Q859614']                   4
# ['Q48270' 'Q12964198']                    4
# ['Q15145779' 'Q1097630']                  4
# ['Q6581097' 'Q6581072']                   3
# ['Q6581072' 'Q6581097']                   2
# ['Q48270' 'Q189125']                      2
# ['Q1289754']                              1
# ['Q2449503' 'Q48270' 'Q12964198']         1
# ['Q1052281' 'Q6581097']                   1
# ['Q48279']                                1
# ['Q6581072' 'Q3277905']                   1
# ['Q6581097' 'Q1097630']                   1
# ['Q6581097' 'Q18116794']                  1
# Name: gender, dtype: int64

# %%
id_description = pd.read_csv('C:\data\wikidata_labels_descriptions.csv.bz2',compression='bz2')
#def process_chunk(chunk):
 #       print(f'Processing chunk with {len(chunk)} rows')
 #       print(chunk.columns)

#with pd.read_csv('C:\data\wikidata_labels_descriptions.csv.bz2',compression='bz2',chunksize=1_000_000) as id_reader:
 #   ids = []
  #  for chunk in id_reader:
   #     process_chunk(chunk)        
        #filt_chunk = filter_speakers(chunk) #filters the lines we want to remove
    #    ids.append(chunk)

#id_description=pd.concat(ids)

# %%
id_description
# Out:
#                  QID                  Label  \
# 0                Q31                Belgium
# 1                 Q8              happiness
# 2                Q23      George Washington
# 3                Q24             Jack Bauer
# 4                Q42          Douglas Adams
# ...              ...                    ...
# 92845808  Q106406593          Irma Dexinger
# 92845809  Q106406600  Coris argenteostriata
# 92845810  Q106406616                    NaN
# 92845811  Q106406643          Fred F. Trull
# 92845812  Q106406647                    NaN
#
#                                                 Description
# 0                                 country in western Europe
# 1         mental or emotional state of well-being charac...
# 2            1st president of the United States (1732–1799)
# 3                   character from the television series 24
# 4                               English writer and humorist
# ...                                                     ...
# 92845808                  Holocaust victim, born 1899-03-18
# 92845809                                                NaN
# 92845810                                                NaN
# 92845811                    politician in Massachusetts, US
# 92845812                                                NaN
#
# [92845813 rows x 3 columns]

# %%
#id_description = id_description[id_description['Label'].notna()] #remove QIDs with NA label

# %%
#remove the [''] for the QIDS in the dff table
#dff['ethnic_group']=dff['ethnic_group'].replace('\[', '',regex=True).replace('\'', '',regex=True).replace('\]', '',regex=True).replace('\'', '',regex=True)
#dff['occupation']=dff['occupation'].replace('\[', '',regex=True).replace('\'', '',regex=True).replace('\]', '',regex=True).replace('\'', '',regex=True)
#dff['academic_degree']=dff['academic_degree'].replace('\[', '',regex=True).replace('\'', '',regex=True).replace('\]', '',regex=True).replace('\'', '',regex=True)
#dff['nationality']=dff['nationality'].replace('\[', '',regex=True).replace('\'', '',regex=True).replace('\]', '',regex=True).replace('\'', '',regex=True)

# %%
#dff

# %%
#replace the QIDS by their labels in the dff table
#dff['ethnic_group'] = dff['ethnic_group'].map(id_description.set_index('QID')['Label'])
#dff['occupation'] = dff['occupation'].map(id_description.set_index('QID')['Label'])
#dff['academic_degree'] = dff['academic_degree'].map(id_description.set_index('QID')['Label'])
#dff['nationality'] = dff['nationality'].map(id_description.set_index('QID')['Label'])

# %%
#dff

# %%
#dff.to_csv("table_with_label.csv")

# %%
#table_with_lable = pd.read_csv('C:\data\table_with_label.csv',low_memory=False)
#featuresQID = pd.read_csv('C:/data/featuresQID.csv',low_memory=False)

# %%
#plot_nationality = dff.groupby(['nationality']).sum().plot(kind='pie',subplots=True)

# %%
#plot_ethnic = dff.groupby(['ethnic_group']).sum().plot(kind='pie',subplots=True)

# %%
#plot_occupation = dff.groupby(['occupation']).sum().plot(kind='pie',subplots=True)

# %%
#plot_degree = dff.groupby(['academic_degree']).sum().plot(kind='pie',subplots=True)

# %%
featuresQID['date_of_birth'].value_counts()
# Out:
# ['+2000-00-00T00:00:00Z']                                                    25845
# ['+1953-01-01T00:00:00Z']                                                    15736
# ['+1950-00-00T00:00:00Z']                                                    14093
# ['+2000-01-01T00:00:00Z']                                                    13739
# ['+1950-01-01T00:00:00Z']                                                    12768
#                                                                              ...
# ['+1813-01-01T00:00:00Z' '+1813-03-22T00:00:00Z']                                1
# ['+1798-01-01T00:00:00Z' '+1797-00-00T00:00:00Z']                                1
# ['+1798-01-01T00:00:00Z' '+1797-11-15T00:00:00Z']                                1
# ['+1790-01-01T00:00:00Z' '+1790-10-04T00:00:00Z']                                1
# ['+1850-01-01T00:00:00Z' '+1884-01-01T00:00:00Z' '+1852-01-01T00:00:00Z']        1
# Name: date_of_birth, Length: 249330, dtype: int64

# %%
#dff['date_of_birth']=dff['date_of_birth'].replace('\+', '',regex=True).replace('\[', '',regex=True).replace('\]', '',regex=True)

# %%
#dff

# %%
#dff['yeat_of_birth'] = dff['date_of_birth'].str[3:7]

# %%
#dff

# %% [markdown]
# ### Counting gender proportions

# %%
def gender(x):
    
    'Function to convert wikidata id into a gender string value'
    'We consider male and female as male/female and transgender male/female respectly'

    if x == "['Q6581097']" or x =="['Q2449503']": #males and transgender males
        return 'male'
    elif x == "['Q6581072']" or  x ==  "['Q1052281']": #females and transgender females
        return 'female'
    elif pd.isna(x):
        return np.nan
    else:
        return 'other'

dff['gen'] = dff['gender'].apply(gender)
dff['gen'].value_counts(dropna=False)
# Out:
# male      575884
# female    111597
# NaN        13523
# other        510
# Name: gen, dtype: int64

# %%
dff
# Out:
#                   quoteID                                          quotation  \
# 0       2020-01-17-000357  [ The delay ] will have an impact [ on Slough ...
# 1       2020-04-02-000239  [ The scheme ] treats addiction as an illness ...
# 2       2020-03-19-000276  [ These ] actions will allow households who ha...
# 3       2020-01-08-000594                   11 straight weeks of pre-season,
# 4       2020-02-21-000455  2019 was a landmark year for Fiverr as we comp...
# ...                   ...                                                ...
# 701509  2020-03-24-093541  You can't get social distance in a submarine a...
# 701510  2020-03-28-040445                              You Know I' m No Good
# 701511  2020-02-02-058890  You understood the structure of our story and ...
# 701512  2020-01-28-115305  You'd probably be able to do that every now an...
# 701513  2020-02-24-080256  You've got to think that long term, it augurs ...
#
#                 speaker       qids                date  numOccurrences  \
# 0          Dexter Smith   Q5268447 2020-01-17 13:03:00               1
# 1       Barry Coppinger   Q4864119 2020-04-02 14:18:20               1
# 2            Ben Carson    Q816459 2020-03-19 19:14:00               1
# 3        Aphelele Fassi  Q56255401 2020-01-08 10:22:11               1
# 4         Micha Kaufman  Q26923564 2020-02-21 13:00:00               1
# ...                 ...        ...                 ...             ...
# 701509       Mark Esper  Q33190271 2020-03-24 22:32:54               1
# 701510    Amy Winehouse     Q15897 2020-03-28 17:00:40               1
# 701511     Bong Joon Ho    Q495980 2020-02-02 08:27:01               4
# 701512  Michael Maguire   Q3856214 2020-01-28 23:26:18               1
# 701513      John Colley  Q18530304 2020-02-24 04:30:00               3
#
#                                                    probas  \
# 0          [['Dexter Smith', '0.924'], ['None', '0.076']]
# 1       [['Barry Coppinger', '0.9017'], ['None', '0.09...
# 2          [['Ben Carson', '0.9227'], ['None', '0.0773']]
# 3       [['Aphelele Fassi', '0.9033'], ['None', '0.096...
# 4       [['Micha Kaufman', '0.9409'], ['None', '0.0591']]
# ...                                                   ...
# 701509     [['Mark Esper', '0.9434'], ['None', '0.0566']]
# 701510  [['Amy Winehouse', '0.9469'], ['None', '0.0477...
# 701511  [['Bong Joon Ho', '0.9476'], ['None', '0.0454'...
# 701512  [['Michael Maguire', '0.9191'], ['None', '0.08...
# 701513      [['John Colley', '0.928'], ['None', '0.072']]
#
#                                                      urls phase  \
# 0       [http://www.sloughexpress.co.uk/gallery/slough...     E
# 1       [http://www.theweek.co.uk/106479/why-police-ar...     E
# 2       [https://mortgageorb.com/hud-fha-suspend-forec...     E
# 3       [https://www.sport24.co.za/Rugby/SuperRugby/sh...     E
# 4       [https://www.fool.com/investing/2020/02/21/why...     E
# ...                                                   ...   ...
# 701509  [https://news.usni.org/2020/03/24/navy-adapts-...     E
# 701510  [https://www.goldderby.com/article/2020/the-ma...     E
# 701511  [https://www.prokerala.com/news/articles/a1003...     E
# 701512  [http://www.nrl.com/news/2020/01/29/tigers-and...     E
# 701513  [http://www.farmweekly.com.au/story/6646057/st...     E
#
#                                           number        gender ethnic_group  \
# 0                                    0.924 0.076  ['Q6581097']          NaN
# 1                                  0.9017 0.0983  ['Q6581097']          NaN
# 2                                  0.9227 0.0773  ['Q6581097']   ['Q49085']
# 3                                  0.9033 0.0967  ['Q6581097']          NaN
# 4                                  0.9409 0.0591  ['Q6581097']          NaN
# ...                                          ...           ...          ...
# 701509                             0.9434 0.0566  ['Q6581097']          NaN
# 701510        0.9469 0.0477 0.0021 0.0019 0.0014  ['Q6581072']          NaN
# 701511  0.9476 0.0454 0.004 0.0015 8.0 -4 7.0 -4  ['Q6581097']          NaN
# 701512                             0.9191 0.0809  ['Q6581097']          NaN
# 701513                               0.928 0.072  ['Q6581097']          NaN
#
#                                                occupation academic_degree  \
# 0                                           ['Q12299841']             NaN
# 1                                                     NaN             NaN
# 2       ['Q212980' 'Q9385011' 'Q82955' 'Q482980' 'Q162...     ['Q913404']
# 3                                           ['Q14089670']             NaN
# 4                                                     NaN             NaN
# ...                                                   ...             ...
# 701509                            ['Q11986654' 'Q189290']             NaN
# 701510  ['Q488205' 'Q855091' 'Q15981151' 'Q6168364' 'Q...             NaN
# 701511                     ['Q2526255' 'Q28389' 'Q82955']             NaN
# 701512                  ['Q4182927' 'Q33999' 'Q10798782']             NaN
# 701513                             ['Q548320' 'Q1234713']             NaN
#
#         nationality              date_of_birth     gen
# 0        ['Q23635']  ['+1961-05-22T00:00:00Z']    male
# 1               NaN                        NaN    male
# 2           ['Q30']  ['+1951-09-18T00:00:00Z']    male
# 3          ['Q258']  ['+1998-01-23T00:00:00Z']    male
# 4          ['Q801']  ['+1946-01-03T00:00:00Z']    male
# ...             ...                        ...     ...
# 701509      ['Q30']  ['+1964-04-26T00:00:00Z']    male
# 701510     ['Q145']  ['+1983-09-14T00:00:00Z']  female
# 701511     ['Q884']  ['+1969-09-14T00:00:00Z']    male
# 701512      ['Q30']  ['+1955-02-20T00:00:00Z']    male
# 701513  ['Q161885']                        NaN    male
#
# [701514 rows x 17 columns]

# %%
import pickle
path ='gen_2020.pickle'
# Store data (serialize)
with open(path, 'wb') as handle:
    pickle.dump(dff[['qids','quoteID','gen']], handle, protocol=pickle.HIGHEST_PROTOCOL)

dff[['qids','quoteID','gen']]
pd.DataFrame.from_dict(data=dff[['qids','quoteID','gen']], orient='columns').to_csv("gen_2020.csv", header=False)

# %%
### First small calculation of proportion of speakers 
import seaborn as sns
male  =   575884 #based on outputed numbers above
female =  111597
Nann   = 13523
other  = 510
total =(male + female +other)
print(f'{male/total:,.2f}% of the speakers are males, {female/total:,.2f}% female,{other/total:,.4f}% other gender or combination')
# Out:
# 0.84% of the speakers are males, 0.16% female,0.0007% other gender or combination

# %%
### plot of the speakers proportion (here for 2020)

ax = sns.countplot(x="gen", data=dff)
ax.set(xlabel='Gender', ylabel='Log [count]')
ax.set_title('Speakers Gender in 2020')
plt.yscale("log")
plt.show()

# %% [markdown]
# ### Pie charts of proportion of women throughout the 6 years:
# cvs files of every year (that were generated one by one on our different computers using the code above) are now being loaded and presented in graphs.

# %%
# pie charts of the results

colnames = ['qids','quoteid','gender']
path = r'C:/data/gen2020'
all_files = glob.glob(path + "/*.csv")

li = []

import matplotlib.pyplot as plotter

year = 2015 #to have the right year on top of every chart. starting at year 2015

for filename in all_files:
    df = pd.read_csv(filename, header = None, index_col=0, names = colnames)
    male = df[df['gender'] == 'male'].gender.count()
    female = df[df['gender'] == 'female'].gender.count()
    other = df[df['gender'] == 'other'].gender.count()
    total = male + female + other
    
    # The slice names of a population distribution pie chart
    labels = ['male','female','other']
    
    # Population data
    sizes = [male/total, female/total, other/total]
    figureObject, axesObject = plotter.subplots()
    
    # Drawing the pie chart
    axesObject.pie(sizes,
        labels=labels,
        autopct='%1.1f%%',
        startangle=90,
        normalize=False)
    
    # Aspect ratio - equal means pie is a circle
    axesObject.axis('equal')
    plt.title(f'Proportion of speakers regarding the gender for year {year}');
    plotter.show()
    
    li.append(df)
    
    year = year + 1 #to go through every year
    

allyears = pd.concat(li, axis=0, ignore_index=True)
allyears['quoteid'] = allyears['quoteid'].str[:-7];
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-24154ca93542> in <module>
#      42
#      43
# ---> 44 allyears = pd.concat(li, axis=0, ignore_index=True)
#      45 allyears['quoteid'] = allyears['quoteid'].str[:-7];
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     302         verify_integrity=verify_integrity,
#     303         copy=copy,
# --> 304         sort=sort,
#     305     )
#     306
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     349
#     350         if len(objs) == 0:
# --> 351             raise ValueError("No objects to concatenate")
#     352
#     353         if keys is None:
#
# ValueError: No objects to concatenate

# %%
### Chart of all years together --> mean

male = allyears[allyears['gender'] == 'male'].gender.count()
female = allyears[allyears['gender'] == 'female'].gender.count()
other = allyears[allyears['gender'] == 'other'].gender.count()
total = male + female + other
# import the pyplot library

import matplotlib.pyplot as plotter
# The slice names of a population distribution pie chart
labels = ['male','female','other']
# Population data
sizes = [male/total, female/total, other/total]
figureObject, axesObject = plotter.subplots()

# Draw the pie chart
axesObject.pie(sizes,
        labels=labels,
        autopct='%1.1f%%',
        startangle=90)
# Aspect ratio - equal means pie is a circle

axesObject.axis('equal')
plt.title('Proportion of speakers regarding the gender for years 2015 to 2020');
plotter.show()

# %% [markdown]
# ## Age, ethnic group...

# %%
df_processed = pd.read_csv('C:/data/fin_2020.csv')

# %%
df_processed.columns = ['id','quids', 'quoteID', 'gender', 'quote','ethnic_group','occupation','academic_degree','nationality','date_of_birth']

# %%
df_processed
# Out:
#             id      quids            quoteID  gender  \
# 0            1   Q4864119  2020-04-02-000239    male
# 1            2    Q816459  2020-03-19-000276    male
# 2            3  Q56255401  2020-01-08-000594    male
# 3            4  Q26923564  2020-02-21-000455    male
# 4            5   Q4749380  2020-04-01-000532  female
# ...        ...        ...                ...     ...
# 701508  701509  Q33190271  2020-03-24-093541    male
# 701509  701510     Q15897  2020-03-28-040445  female
# 701510  701511    Q495980  2020-02-02-058890    male
# 701511  701512   Q3856214  2020-01-28-115305    male
# 701512  701513  Q18530304  2020-02-24-080256    male
#
#                                                     quote  \
# 0       [ The scheme ] treats addiction as an illness ...
# 1       [ These ] actions will allow households who ha...
# 2                        11 straight weeks of pre-season,
# 3       2019 was a landmark year for Fiverr as we comp...
# 4       7pm is when most hospitals change shifts. That...
# ...                                                   ...
# 701508  You can't get social distance in a submarine a...
# 701509                              You Know I' m No Good
# 701510  You understood the structure of our story and ...
# 701511  You'd probably be able to do that every now an...
# 701512  You've got to think that long term, it augurs ...
#
#                   ethnic_group  \
# 0                          NaN
# 1                   ['Q49085']
# 2                          NaN
# 3                          NaN
# 4       ['Q678551' 'Q2505231']
# ...                        ...
# 701508                     NaN
# 701509                     NaN
# 701510                     NaN
# 701511                     NaN
# 701512                     NaN
#
#                                                occupation academic_degree  \
# 0                                                     NaN             NaN
# 1       ['Q212980' 'Q9385011' 'Q82955' 'Q482980' 'Q162...     ['Q913404']
# 2                                           ['Q14089670']             NaN
# 3                                                     NaN             NaN
# 4       ['Q33999' 'Q36180' 'Q28389' 'Q578109' 'Q245068...             NaN
# ...                                                   ...             ...
# 701508                            ['Q11986654' 'Q189290']             NaN
# 701509  ['Q488205' 'Q855091' 'Q15981151' 'Q6168364' 'Q...             NaN
# 701510                     ['Q2526255' 'Q28389' 'Q82955']             NaN
# 701511                  ['Q4182927' 'Q33999' 'Q10798782']             NaN
# 701512                             ['Q548320' 'Q1234713']             NaN
#
#         nationality              date_of_birth
# 0               NaN                        NaN
# 1           ['Q30']  ['+1951-09-18T00:00:00Z']
# 2          ['Q258']  ['+1998-01-23T00:00:00Z']
# 3          ['Q801']  ['+1946-01-03T00:00:00Z']
# 4           ['Q30']  ['+1981-06-01T00:00:00Z']
# ...             ...                        ...
# 701508      ['Q30']  ['+1964-04-26T00:00:00Z']
# 701509     ['Q145']  ['+1983-09-14T00:00:00Z']
# 701510     ['Q884']  ['+1969-09-14T00:00:00Z']
# 701511      ['Q30']  ['+1955-02-20T00:00:00Z']
# 701512  ['Q161885']                        NaN
#
# [701513 rows x 10 columns]

# %%
#remove the [''] for the QIDS in the dff table
df_processed['ethnic_group']=df_processed['ethnic_group'].replace('\[', '',regex=True).replace('\'', '',regex=True).replace('\]', '',regex=True).replace('\'', '',regex=True)
df_processed['occupation']=df_processed['occupation'].replace('\[', '',regex=True).replace('\'', '',regex=True).replace('\]', '',regex=True).replace('\'', '',regex=True)
df_processed['academic_degree']=df_processed['academic_degree'].replace('\[', '',regex=True).replace('\'', '',regex=True).replace('\]', '',regex=True).replace('\'', '',regex=True)
df_processed['nationality']=df_processed['nationality'].replace('\[', '',regex=True).replace('\'', '',regex=True).replace('\]', '',regex=True).replace('\'', '',regex=True)

#replace the QIDS by their labels in the dff table
df_processed['ethnic_group'] = df_processed['ethnic_group'].map(id_description.set_index('QID')['Label'])
df_processed['occupation'] = df_processed['occupation'].map(id_description.set_index('QID')['Label'])
df_processed['academic_degree'] = df_processed['academic_degree'].map(id_description.set_index('QID')['Label'])
df_processed['nationality'] = df_processed['nationality'].map(id_description.set_index('QID')['Label'])

#get the year of birth of the speaker
df_processed['year_of_birth'] = df_processed['date_of_birth'].str[3:7]

df_processed
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-51-10ca94f8ff30> in <module>
#       6
#       7 #replace the QIDS by their labels in the dff table
# ----> 8 df_processed['ethnic_group'] = df_processed['ethnic_group'].map(id_description.set_index('QID')['Label'])
#       9 df_processed['occupation'] = df_processed['occupation'].map(id_description.set_index('QID')['Label'])
#      10 df_processed['academic_degree'] = df_processed['academic_degree'].map(id_description.set_index('QID')['Label'])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5504                 )
#    5505
# -> 5506         index = ensure_index_from_sequences(arrays, names)
#    5507
#    5508         if verify_integrity and not index.is_unique:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in ensure_index_from_sequences(sequences, names)
#    6272         if names is not None:
#    6273             names = names[0]
# -> 6274         return Index(sequences[0], name=names)
#    6275     else:
#    6276         return MultiIndex.from_arrays(sequences, names=names)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     460
#     461                 if dtype is None:
# --> 462                     arr = _maybe_cast_data_without_dtype(arr)
#     463                     dtype = arr.dtype
#     464
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _maybe_cast_data_without_dtype(subarr)
#    6415         convert_period=True,
#    6416         convert_interval=True,
# -> 6417         dtype_if_all_nat=np.dtype("datetime64[ns]"),
#    6418     )
#    6419     if result.dtype.kind in ["b", "c"]:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_objects()
#
# MemoryError: Unable to allocate 708. MiB for an array with shape (92845813,) and data type timedelta64[ns]

# %%
plot_birth = df_processed.groupby(['year_of_birth']).sum().plot(kind='pie',subplots=True)

# %%
df_processed.loc[df_processed['year_of_birth']=='0015']
# Out:
#                   quoteID                                          quotation  \
# 146727  2020-01-15-021521  God is not a Christian. God is not a religion,...
# 298479  2020-01-14-030884  I realised Castro knew what he was doing. I ga...
#
#              speaker       qids                date  numOccurrences  \
# 146727  Kofi Kinaata  Q24039677 2020-01-15 18:40:11               1
# 298479  Kofi Kinaata  Q24039677 2020-01-14 17:15:00               2
#
#                                                  probas  \
# 146727   [['Kofi Kinaata', '0.934'], ['None', '0.066']]
# 298479  [['Kofi Kinaata', '0.9391'], ['None', '0.061']]
#
#                                                      urls phase        number  \
# 146727  [https://www.pulse.com.gh/entertainment/celebr...     E   0.934 0.066
# 298479  [http://modernghana.com/entertainment/62238/ko...     E  0.9391 0.061
#
#               gender ethnic_group occupation academic_degree nationality  \
# 146727  ['Q6581097']          NaN        NaN             NaN       Ghana
# 298479  ['Q6581097']          NaN        NaN             NaN       Ghana
#
#                     date_of_birth   gen yeat_of_birth
# 146727  ['+0015-04-00T00:00:00Z']  male          0015
# 298479  ['+0015-04-00T00:00:00Z']  male          0015
