# %%
import time
import json
import bz2
import pandas as pd
import numpy as np

#import jsonlines

# %%
###  IMPORTING DATA ###

# Define the path where the data is located

Path = "../quotes-2020.json.bz2" #goes out of the current folder

# %%
#Filtering functions

def filter_speakers(chunk_data):
    #remove the lines with no speaker
    filt_none = chunk_data.drop(chunk_data[chunk_data['speaker'] == 'None'].index)
    return filt_none

# %%
def process_chunk(chunk):
        print(f'Processing chunk with {len(chunk)} rows')
        print(chunk.columns)

with pd.read_json(Path, lines=True, compression='bz2', chunksize=1_000_000) as df_reader:
    dfs = []
    for chunk in df_reader:
        process_chunk(chunk)
        #filt_chunk = chunk.drop(chunk[chunk['speaker'] == 'None'].index)
        filt_chunk = filter_speakers(chunk)
        dfs.append(filt_chunk)
        #dfs.to_json(compression='bz2')
# Out:
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 244449 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')

# %%
#chunk.drop(chunk[chunk['numOccurrences'] == 1].index)

chunk
# Out:
#                    quoteID                                          quotation  \
# 5000000  2020-03-06-047752  People get killed in wildlife collisions, most...
# 5000001  2020-01-31-070691  People my age and older have to figure out how...
# 5000002  2020-03-26-047932  People now have time on their hands and they w...
# 5000003  2020-01-10-061824  People should not recourse to violent methods ...
# 5000004  2020-04-02-047663  People think it's novel that 80-year-olds are ...
# ...                    ...                                                ...
# 5244444  2020-02-24-080186  you're seeing a young team that's maturing, th...
# 5244445  2020-02-07-122251  You're talking about African-Americans, right?...
# 5244446  2020-02-27-098715  You've got to own the team. I see Broosky and ...
# 5244447  2020-02-04-118820  You've got to sometimes take that leap of fait...
# 5244448  2020-02-24-080256  You've got to think that long term, it augurs ...
#
#                       speaker  \
# 5000000          Dave Marsden
# 5000001       Michelle Buteau
# 5000002             Gary Gray
# 5000003         Peter Machado
# 5000004         Candace Owens
# ...                       ...
# 5244444       Brendan Whittet
# 5244445  Barry Michael Cooper
# 5244446                  None
# 5244447           Brad Gushue
# 5244448           John Colley
#
#                                                       qids  \
# 5000000                                         [Q5240722]
# 5000001                                        [Q54861496]
# 5000002  [Q21228842, Q3758498, Q5525157, Q5525158, Q552...
# 5000003                                         [Q1385539]
# 5000004                                        [Q43302090]
# ...                                                    ...
# 5244444                                        [Q18115465]
# 5244445                                         [Q3635235]
# 5244446                                                 []
# 5244447                                          [Q896796]
# 5244448                                        [Q18530304]
#
#                        date  numOccurrences  \
# 5000000 2020-03-06 17:20:36               3
# 5000001 2020-01-31 17:47:00               2
# 5000002 2020-03-26 19:43:00               1
# 5000003 2020-01-10 03:04:23               1
# 5000004 2020-04-02 12:27:27               2
# ...                     ...             ...
# 5244444 2020-02-24 05:00:28               1
# 5244445 2020-02-07 00:00:00               1
# 5244446 2020-02-27 05:59:00               1
# 5244447 2020-02-04 14:47:00              10
# 5244448 2020-02-24 04:30:00               3
#
#                                                     probas  \
# 5000000           [[Dave Marsden, 0.6329], [None, 0.3671]]
# 5000001        [[Michelle Buteau, 0.8651], [None, 0.1349]]
# 5000002              [[Gary Gray, 0.8611], [None, 0.1389]]
# 5000003          [[Peter Machado, 0.9013], [None, 0.0987]]
# 5000004  [[Candace Owens, 0.7324], [Anthony Fauci, 0.17...
# ...                                                    ...
# 5244444        [[Brendan Whittet, 0.7077], [None, 0.2923]]
# 5244445   [[Barry Michael Cooper, 0.5605], [None, 0.4395]]
# 5244446  [[None, 0.8899], [Trent Barrett, 0.0539], [Mic...
# 5244447  [[Brad Gushue, 0.706], [None, 0.2919], [John E...
# 5244448              [[John Colley, 0.928], [None, 0.072]]
#
#                                                       urls phase
# 5000000  [http://www.washingtontimes.com/news/2020/mar/...     E
# 5000001  [https://www.nbcnews.com/news/nbcblk/michelle-...     E
# 5000002  [http://capenews.net/sandwich/news/business-is...     E
# 5000003     [https://www.newkerala.com/news/2020/4460.htm]     E
# 5000004  [https://www.news18.com/news/world/alarm-denia...     E
# ...                                                    ...   ...
# 5244444  [http://feeds.browndailyherald.com/~r/BrownDai...     E
# 5244445  [https://www.villagevoice.com/2020/02/07/1980-...     E
# 5244446  [https://www.foxsports.com.au/nrl/nrl-premiers...     E
# 5244447  [http://timescolonist.com/in-the-rings-steski-...     E
# 5244448  [http://www.farmweekly.com.au/story/6646057/st...     E
#
# [244449 rows x 9 columns]

# %%
chunk.dtypes['probas']
chunk.dtypes['qids']
# Out:
# dtype('O')

# %%
#TESTS
#chunk.query('numOccurrences > 2')
#chunk.drop(chunk[chunk['speaker'] == 'None'].index)
#chunk.query('qids != []')
#chunk['probas'] = chunk['probas'].astype('str') 
#chunk['qids'] = np.int64(chunk.qids)
#chunk.dtypes['numOccurrences']

# %%
pd.concat(dfs)
# Out:
#                    quoteID                                          quotation  \
# 1        2020-01-16-000088  [ Department of Homeland Security ] was livid ...
# 4        2020-01-24-000168  [ I met them ] when they just turned 4 and 7. ...
# 7        2020-01-17-000357  [ The delay ] will have an impact [ on Slough ...
# 8        2020-04-02-000239  [ The scheme ] treats addiction as an illness ...
# 9        2020-03-19-000276  [ These ] actions will allow households who ha...
# ...                    ...                                                ...
# 5244442  2020-03-03-079268  you're going to take care of the gun problem w...
# 5244444  2020-02-24-080186  you're seeing a young team that's maturing, th...
# 5244445  2020-02-07-122251  You're talking about African-Americans, right?...
# 5244447  2020-02-04-118820  You've got to sometimes take that leap of fait...
# 5244448  2020-02-24-080256  You've got to think that long term, it augurs ...
#
#                       speaker         qids                date  \
# 1                  Sue Myrick    [Q367796] 2020-01-16 12:00:13
# 4         Meghan King Edmonds  [Q20684375] 2020-01-24 20:37:09
# 7                Dexter Smith   [Q5268447] 2020-01-17 13:03:00
# 8             Barry Coppinger   [Q4864119] 2020-04-02 14:18:20
# 9                  Ben Carson    [Q816459] 2020-03-19 19:14:00
# ...                       ...          ...                 ...
# 5244442             Joe Biden      [Q6279] 2020-03-03 15:49:51
# 5244444       Brendan Whittet  [Q18115465] 2020-02-24 05:00:28
# 5244445  Barry Michael Cooper   [Q3635235] 2020-02-07 00:00:00
# 5244447           Brad Gushue    [Q896796] 2020-02-04 14:47:00
# 5244448           John Colley  [Q18530304] 2020-02-24 04:30:00
#
#          numOccurrences                                             probas  \
# 1                     1  [[Sue Myrick, 0.8867], [None, 0.0992], [Ron Wy...
# 4                     4  [[Meghan King Edmonds, 0.5446], [None, 0.2705]...
# 7                     1             [[Dexter Smith, 0.924], [None, 0.076]]
# 8                     1        [[Barry Coppinger, 0.9017], [None, 0.0983]]
# 9                     1             [[Ben Carson, 0.9227], [None, 0.0773]]
# ...                 ...                                                ...
# 5244442               2  [[Joe Biden, 0.6777], [Beto O'Rourke, 0.2017],...
# 5244444               1        [[Brendan Whittet, 0.7077], [None, 0.2923]]
# 5244445               1   [[Barry Michael Cooper, 0.5605], [None, 0.4395]]
# 5244447              10  [[Brad Gushue, 0.706], [None, 0.2919], [John E...
# 5244448               3              [[John Colley, 0.928], [None, 0.072]]
#
#                                                       urls phase
# 1        [http://thehill.com/opinion/international/4782...     E
# 4        [https://people.com/parents/meghan-king-edmond...     E
# 7        [http://www.sloughexpress.co.uk/gallery/slough...     E
# 8        [http://www.theweek.co.uk/106479/why-police-ar...     E
# 9        [https://mortgageorb.com/hud-fha-suspend-forec...     E
# ...                                                    ...   ...
# 5244442  [https://twitchy.com/gregp-3534/2020/03/03/did...     E
# 5244444  [http://feeds.browndailyherald.com/~r/BrownDai...     E
# 5244445  [https://www.villagevoice.com/2020/02/07/1980-...     E
# 5244447  [http://timescolonist.com/in-the-rings-steski-...     E
# 5244448  [http://www.farmweekly.com.au/story/6646057/st...     E
#
# [3443605 rows x 9 columns]

# %%
#def filter_speakers(chunk_data):
 #   filt_none = chunk_data.drop(chunk_data[chunk_data['speaker'] == 'None'].index)
  #  return filt_none

# %%
filt_chunk
# Out:
#                    quoteID                                          quotation  \
# 5000000  2020-03-06-047752  People get killed in wildlife collisions, most...
# 5000001  2020-01-31-070691  People my age and older have to figure out how...
# 5000002  2020-03-26-047932  People now have time on their hands and they w...
# 5000003  2020-01-10-061824  People should not recourse to violent methods ...
# 5000004  2020-04-02-047663  People think it's novel that 80-year-olds are ...
# ...                    ...                                                ...
# 5244442  2020-03-03-079268  you're going to take care of the gun problem w...
# 5244444  2020-02-24-080186  you're seeing a young team that's maturing, th...
# 5244445  2020-02-07-122251  You're talking about African-Americans, right?...
# 5244447  2020-02-04-118820  You've got to sometimes take that leap of fait...
# 5244448  2020-02-24-080256  You've got to think that long term, it augurs ...
#
#                       speaker  \
# 5000000          Dave Marsden
# 5000001       Michelle Buteau
# 5000002             Gary Gray
# 5000003         Peter Machado
# 5000004         Candace Owens
# ...                       ...
# 5244442             Joe Biden
# 5244444       Brendan Whittet
# 5244445  Barry Michael Cooper
# 5244447           Brad Gushue
# 5244448           John Colley
#
#                                                       qids  \
# 5000000                                         [Q5240722]
# 5000001                                        [Q54861496]
# 5000002  [Q21228842, Q3758498, Q5525157, Q5525158, Q552...
# 5000003                                         [Q1385539]
# 5000004                                        [Q43302090]
# ...                                                    ...
# 5244442                                            [Q6279]
# 5244444                                        [Q18115465]
# 5244445                                         [Q3635235]
# 5244447                                          [Q896796]
# 5244448                                        [Q18530304]
#
#                        date  numOccurrences  \
# 5000000 2020-03-06 17:20:36               3
# 5000001 2020-01-31 17:47:00               2
# 5000002 2020-03-26 19:43:00               1
# 5000003 2020-01-10 03:04:23               1
# 5000004 2020-04-02 12:27:27               2
# ...                     ...             ...
# 5244442 2020-03-03 15:49:51               2
# 5244444 2020-02-24 05:00:28               1
# 5244445 2020-02-07 00:00:00               1
# 5244447 2020-02-04 14:47:00              10
# 5244448 2020-02-24 04:30:00               3
#
#                                                     probas  \
# 5000000           [[Dave Marsden, 0.6329], [None, 0.3671]]
# 5000001        [[Michelle Buteau, 0.8651], [None, 0.1349]]
# 5000002              [[Gary Gray, 0.8611], [None, 0.1389]]
# 5000003          [[Peter Machado, 0.9013], [None, 0.0987]]
# 5000004  [[Candace Owens, 0.7324], [Anthony Fauci, 0.17...
# ...                                                    ...
# 5244442  [[Joe Biden, 0.6777], [Beto O'Rourke, 0.2017],...
# 5244444        [[Brendan Whittet, 0.7077], [None, 0.2923]]
# 5244445   [[Barry Michael Cooper, 0.5605], [None, 0.4395]]
# 5244447  [[Brad Gushue, 0.706], [None, 0.2919], [John E...
# 5244448              [[John Colley, 0.928], [None, 0.072]]
#
#                                                       urls phase
# 5000000  [http://www.washingtontimes.com/news/2020/mar/...     E
# 5000001  [https://www.nbcnews.com/news/nbcblk/michelle-...     E
# 5000002  [http://capenews.net/sandwich/news/business-is...     E
# 5000003     [https://www.newkerala.com/news/2020/4460.htm]     E
# 5000004  [https://www.news18.com/news/world/alarm-denia...     E
# ...                                                    ...   ...
# 5244442  [https://twitchy.com/gregp-3534/2020/03/03/did...     E
# 5244444  [http://feeds.browndailyherald.com/~r/BrownDai...     E
# 5244445  [https://www.villagevoice.com/2020/02/07/1980-...     E
# 5244447  [http://timescolonist.com/in-the-rings-steski-...     E
# 5244448  [http://www.farmweekly.com.au/story/6646057/st...     E
#
# [160321 rows x 9 columns]
