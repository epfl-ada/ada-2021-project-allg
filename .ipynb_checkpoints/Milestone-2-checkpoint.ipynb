# %%
import time
import json
import bz2
import pandas as pd
import numpy as np
import re

#import jsonlines

# %%
###  IMPORTING DATA ###

# Define the path where the data is located

Path = "../quotes-2020.json.bz2" #goes out of the current folder

# %%
#Filtering functions

def find_proba(text):
    num = re.findall(r'-?\d+\.?\d*',text)
    return " ".join(num)

def filter_speakers(chunk_data):
    #remove the lines with no speaker
    #filt_none = chunk_data.drop(chunk_data[chunk_data['speaker'] == 'None'].index)
    chunk_data['probas']=str(chunk_data['probas'])
    chunk_data['number'] = chunk_data['probas'].apply(lambda x: find_proba(x))
    filt_prob = chunk_data.drop(chunk_data[chunk_data['number'] < '0.9'].index)
    return filt_prob

# %%
def process_chunk(chunk):
        print(f'Processing chunk with {len(chunk)} rows')
        print(chunk.columns)

with pd.read_json(Path, lines=True, compression='bz2', chunksize=1_000_000) as df_reader:
    dfs = []
    for chunk in df_reader:
        process_chunk(chunk)
        #filt_chunk = chunk.drop(chunk[chunk['speaker'] == 'None'].index)
        #chunk['number']=chunk['probas'].apply(lambda x: find_proba(x))
        #chunk.drop(chunk[chunk['number'] < '0.9'].index)
        
        filt_chunk = filter_speakers(chunk)
        dfs.append(filt_chunk)
        
        #dfs.to_json(compression='bz2')
# Out:
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 244449 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')

# %%
#chunk.drop(chunk[chunk['numOccurrences'] == 1].index)

chunk
# Out:
#                    quoteID                                          quotation  \
# 5000000  2020-03-06-047752  People get killed in wildlife collisions, most...
# 5000001  2020-01-31-070691  People my age and older have to figure out how...
# 5000002  2020-03-26-047932  People now have time on their hands and they w...
# 5000003  2020-01-10-061824  People should not recourse to violent methods ...
# 5000004  2020-04-02-047663  People think it's novel that 80-year-olds are ...
# ...                    ...                                                ...
# 5244444  2020-02-24-080186  you're seeing a young team that's maturing, th...
# 5244445  2020-02-07-122251  You're talking about African-Americans, right?...
# 5244446  2020-02-27-098715  You've got to own the team. I see Broosky and ...
# 5244447  2020-02-04-118820  You've got to sometimes take that leap of fait...
# 5244448  2020-02-24-080256  You've got to think that long term, it augurs ...
#
#                       speaker  \
# 5000000          Dave Marsden
# 5000001       Michelle Buteau
# 5000002             Gary Gray
# 5000003         Peter Machado
# 5000004         Candace Owens
# ...                       ...
# 5244444       Brendan Whittet
# 5244445  Barry Michael Cooper
# 5244446                  None
# 5244447           Brad Gushue
# 5244448           John Colley
#
#                                                       qids  \
# 5000000                                         [Q5240722]
# 5000001                                        [Q54861496]
# 5000002  [Q21228842, Q3758498, Q5525157, Q5525158, Q552...
# 5000003                                         [Q1385539]
# 5000004                                        [Q43302090]
# ...                                                    ...
# 5244444                                        [Q18115465]
# 5244445                                         [Q3635235]
# 5244446                                                 []
# 5244447                                          [Q896796]
# 5244448                                        [Q18530304]
#
#                        date  numOccurrences  \
# 5000000 2020-03-06 17:20:36               3
# 5000001 2020-01-31 17:47:00               2
# 5000002 2020-03-26 19:43:00               1
# 5000003 2020-01-10 03:04:23               1
# 5000004 2020-04-02 12:27:27               2
# ...                     ...             ...
# 5244444 2020-02-24 05:00:28               1
# 5244445 2020-02-07 00:00:00               1
# 5244446 2020-02-27 05:59:00               1
# 5244447 2020-02-04 14:47:00              10
# 5244448 2020-02-24 04:30:00               3
#
#                                                     probas  \
# 5000000  5000000             [[Dave Marsden, 0.6329], [...
# 5000001  5000000             [[Dave Marsden, 0.6329], [...
# 5000002  5000000             [[Dave Marsden, 0.6329], [...
# 5000003  5000000             [[Dave Marsden, 0.6329], [...
# 5000004  5000000             [[Dave Marsden, 0.6329], [...
# ...                                                    ...
# 5244444  5000000             [[Dave Marsden, 0.6329], [...
# 5244445  5000000             [[Dave Marsden, 0.6329], [...
# 5244446  5000000             [[Dave Marsden, 0.6329], [...
# 5244447  5000000             [[Dave Marsden, 0.6329], [...
# 5244448  5000000             [[Dave Marsden, 0.6329], [...
#
#                                                       urls phase  \
# 5000000  [http://www.washingtontimes.com/news/2020/mar/...     E
# 5000001  [https://www.nbcnews.com/news/nbcblk/michelle-...     E
# 5000002  [http://capenews.net/sandwich/news/business-is...     E
# 5000003     [https://www.newkerala.com/news/2020/4460.htm]     E
# 5000004  [https://www.news18.com/news/world/alarm-denia...     E
# ...                                                    ...   ...
# 5244444  [http://feeds.browndailyherald.com/~r/BrownDai...     E
# 5244445  [https://www.villagevoice.com/2020/02/07/1980-...     E
# 5244446  [https://www.foxsports.com.au/nrl/nrl-premiers...     E
# 5244447  [http://timescolonist.com/in-the-rings-steski-...     E
# 5244448  [http://www.farmweekly.com.au/story/6646057/st...     E
#
#                                                     number
# 5000000  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000001  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000002  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000003  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000004  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# ...                                                    ...
# 5244444  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244445  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244446  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244447  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244448  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
#
# [244449 rows x 10 columns]

# %%
#filt_chunk = filter_speakers(chunk)
#filt_chunk

# %%
chunk.dtypes['probas']
chunk.dtypes['qids']
# Out:
# dtype('O')

# %%
#TESTS
#chunk.query('numOccurrences > 2')
#chunk.drop(chunk[chunk['speaker'] == 'None'].index)
#chunk.query('qids != []')
#chunk['probas'] = chunk['probas'].astype('str') 
#chunk['qids'] = np.int64(chunk.qids)
#chunk.dtypes['numOccurrences']

# %%
pd.concat(dfs)
# Out:
#                    quoteID                                          quotation  \
# 1000000  2020-03-05-043035  I've had some mates around to my apartment. On...
# 1000001  2020-04-16-030931  I've never put a single person in the Navy hop...
# 1000002  2020-02-07-056719  I've never really had an opportunity to do som...
# 1000003  2020-03-03-036061  I've seen him grow from nowhere. Mukesh Kumar ...
# 1000004  2020-02-03-049559  I've seen technology really blossom as well as...
# ...                    ...                                                ...
# 5244444  2020-02-24-080186  you're seeing a young team that's maturing, th...
# 5244445  2020-02-07-122251  You're talking about African-Americans, right?...
# 5244446  2020-02-27-098715  You've got to own the team. I see Broosky and ...
# 5244447  2020-02-04-118820  You've got to sometimes take that leap of fait...
# 5244448  2020-02-24-080256  You've got to think that long term, it augurs ...
#
#                       speaker                              qids  \
# 1000000                  None                                []
# 1000001          Brian Austin  [Q19942557, Q48049194, Q4963008]
# 1000002            Jeff Baena                       [Q26897001]
# 1000003          Ranadeb Bose                       [Q13059525]
# 1000004            GEOFF TATE                         [Q551619]
# ...                       ...                               ...
# 5244444       Brendan Whittet                       [Q18115465]
# 5244445  Barry Michael Cooper                        [Q3635235]
# 5244446                  None                                []
# 5244447           Brad Gushue                         [Q896796]
# 5244448           John Colley                       [Q18530304]
#
#                        date  numOccurrences  \
# 1000000 2020-03-05 15:27:43               1
# 1000001 2020-04-16 18:46:53               1
# 1000002 2020-02-07 21:30:58               1
# 1000003 2020-03-03 13:33:00               1
# 1000004 2020-02-03 16:01:38               1
# ...                     ...             ...
# 5244444 2020-02-24 05:00:28               1
# 5244445 2020-02-07 00:00:00               1
# 5244446 2020-02-27 05:59:00               1
# 5244447 2020-02-04 14:47:00              10
# 5244448 2020-02-24 04:30:00               3
#
#                                                     probas  \
# 1000000  1000000            [[None, 0.8065], [Boris Joh...
# 1000001  1000000            [[None, 0.8065], [Boris Joh...
# 1000002  1000000            [[None, 0.8065], [Boris Joh...
# 1000003  1000000            [[None, 0.8065], [Boris Joh...
# 1000004  1000000            [[None, 0.8065], [Boris Joh...
# ...                                                    ...
# 5244444  5000000             [[Dave Marsden, 0.6329], [...
# 5244445  5000000             [[Dave Marsden, 0.6329], [...
# 5244446  5000000             [[Dave Marsden, 0.6329], [...
# 5244447  5000000             [[Dave Marsden, 0.6329], [...
# 5244448  5000000             [[Dave Marsden, 0.6329], [...
#
#                                                       urls phase  \
# 1000000  [https://www.manchestereveningnews.co.uk/news/...     E
# 1000001  [https://www.dvidshub.net/news/367578/navy-rec...     E
# 1000002  [https://decider.com/2020/02/07/horse-girl-end...     E
# 1000003  [http://timesofindia.indiatimes.com/sports/cri...     E
# 1000004  [https://www.blabbermouth.net/news/geoff-tate-...     E
# ...                                                    ...   ...
# 5244444  [http://feeds.browndailyherald.com/~r/BrownDai...     E
# 5244445  [https://www.villagevoice.com/2020/02/07/1980-...     E
# 5244446  [https://www.foxsports.com.au/nrl/nrl-premiers...     E
# 5244447  [http://timescolonist.com/in-the-rings-steski-...     E
# 5244448  [http://www.farmweekly.com.au/story/6646057/st...     E
#
#                                                     number
# 1000000  1000000 0.8065 0.1935 1000001 0.8695 0.1305 10...
# 1000001  1000000 0.8065 0.1935 1000001 0.8695 0.1305 10...
# 1000002  1000000 0.8065 0.1935 1000001 0.8695 0.1305 10...
# 1000003  1000000 0.8065 0.1935 1000001 0.8695 0.1305 10...
# 1000004  1000000 0.8065 0.1935 1000001 0.8695 0.1305 10...
# ...                                                    ...
# 5244444  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244445  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244446  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244447  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244448  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
#
# [4244449 rows x 10 columns]

# %%
#def filter_speakers(chunk_data):
 #   filt_none = chunk_data.drop(chunk_data[chunk_data['speaker'] == 'None'].index)
  #  return filt_none

# %%
filt_chunk
# Out:
#                    quoteID                                          quotation  \
# 5000000  2020-03-06-047752  People get killed in wildlife collisions, most...
# 5000001  2020-01-31-070691  People my age and older have to figure out how...
# 5000002  2020-03-26-047932  People now have time on their hands and they w...
# 5000003  2020-01-10-061824  People should not recourse to violent methods ...
# 5000004  2020-04-02-047663  People think it's novel that 80-year-olds are ...
# ...                    ...                                                ...
# 5244444  2020-02-24-080186  you're seeing a young team that's maturing, th...
# 5244445  2020-02-07-122251  You're talking about African-Americans, right?...
# 5244446  2020-02-27-098715  You've got to own the team. I see Broosky and ...
# 5244447  2020-02-04-118820  You've got to sometimes take that leap of fait...
# 5244448  2020-02-24-080256  You've got to think that long term, it augurs ...
#
#                       speaker  \
# 5000000          Dave Marsden
# 5000001       Michelle Buteau
# 5000002             Gary Gray
# 5000003         Peter Machado
# 5000004         Candace Owens
# ...                       ...
# 5244444       Brendan Whittet
# 5244445  Barry Michael Cooper
# 5244446                  None
# 5244447           Brad Gushue
# 5244448           John Colley
#
#                                                       qids  \
# 5000000                                         [Q5240722]
# 5000001                                        [Q54861496]
# 5000002  [Q21228842, Q3758498, Q5525157, Q5525158, Q552...
# 5000003                                         [Q1385539]
# 5000004                                        [Q43302090]
# ...                                                    ...
# 5244444                                        [Q18115465]
# 5244445                                         [Q3635235]
# 5244446                                                 []
# 5244447                                          [Q896796]
# 5244448                                        [Q18530304]
#
#                        date  numOccurrences  \
# 5000000 2020-03-06 17:20:36               3
# 5000001 2020-01-31 17:47:00               2
# 5000002 2020-03-26 19:43:00               1
# 5000003 2020-01-10 03:04:23               1
# 5000004 2020-04-02 12:27:27               2
# ...                     ...             ...
# 5244444 2020-02-24 05:00:28               1
# 5244445 2020-02-07 00:00:00               1
# 5244446 2020-02-27 05:59:00               1
# 5244447 2020-02-04 14:47:00              10
# 5244448 2020-02-24 04:30:00               3
#
#                                                     probas  \
# 5000000  5000000             [[Dave Marsden, 0.6329], [...
# 5000001  5000000             [[Dave Marsden, 0.6329], [...
# 5000002  5000000             [[Dave Marsden, 0.6329], [...
# 5000003  5000000             [[Dave Marsden, 0.6329], [...
# 5000004  5000000             [[Dave Marsden, 0.6329], [...
# ...                                                    ...
# 5244444  5000000             [[Dave Marsden, 0.6329], [...
# 5244445  5000000             [[Dave Marsden, 0.6329], [...
# 5244446  5000000             [[Dave Marsden, 0.6329], [...
# 5244447  5000000             [[Dave Marsden, 0.6329], [...
# 5244448  5000000             [[Dave Marsden, 0.6329], [...
#
#                                                       urls phase  \
# 5000000  [http://www.washingtontimes.com/news/2020/mar/...     E
# 5000001  [https://www.nbcnews.com/news/nbcblk/michelle-...     E
# 5000002  [http://capenews.net/sandwich/news/business-is...     E
# 5000003     [https://www.newkerala.com/news/2020/4460.htm]     E
# 5000004  [https://www.news18.com/news/world/alarm-denia...     E
# ...                                                    ...   ...
# 5244444  [http://feeds.browndailyherald.com/~r/BrownDai...     E
# 5244445  [https://www.villagevoice.com/2020/02/07/1980-...     E
# 5244446  [https://www.foxsports.com.au/nrl/nrl-premiers...     E
# 5244447  [http://timescolonist.com/in-the-rings-steski-...     E
# 5244448  [http://www.farmweekly.com.au/story/6646057/st...     E
#
#                                                     number
# 5000000  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000001  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000002  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000003  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000004  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# ...                                                    ...
# 5244444  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244445  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244446  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244447  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244448  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
#
# [244449 rows x 10 columns]

# %%
chunk
# Out:
#                    quoteID                                          quotation  \
# 5000000  2020-03-06-047752  People get killed in wildlife collisions, most...
# 5000001  2020-01-31-070691  People my age and older have to figure out how...
# 5000002  2020-03-26-047932  People now have time on their hands and they w...
# 5000003  2020-01-10-061824  People should not recourse to violent methods ...
# 5000004  2020-04-02-047663  People think it's novel that 80-year-olds are ...
# ...                    ...                                                ...
# 5244444  2020-02-24-080186  you're seeing a young team that's maturing, th...
# 5244445  2020-02-07-122251  You're talking about African-Americans, right?...
# 5244446  2020-02-27-098715  You've got to own the team. I see Broosky and ...
# 5244447  2020-02-04-118820  You've got to sometimes take that leap of fait...
# 5244448  2020-02-24-080256  You've got to think that long term, it augurs ...
#
#                       speaker  \
# 5000000          Dave Marsden
# 5000001       Michelle Buteau
# 5000002             Gary Gray
# 5000003         Peter Machado
# 5000004         Candace Owens
# ...                       ...
# 5244444       Brendan Whittet
# 5244445  Barry Michael Cooper
# 5244446                  None
# 5244447           Brad Gushue
# 5244448           John Colley
#
#                                                       qids  \
# 5000000                                         [Q5240722]
# 5000001                                        [Q54861496]
# 5000002  [Q21228842, Q3758498, Q5525157, Q5525158, Q552...
# 5000003                                         [Q1385539]
# 5000004                                        [Q43302090]
# ...                                                    ...
# 5244444                                        [Q18115465]
# 5244445                                         [Q3635235]
# 5244446                                                 []
# 5244447                                          [Q896796]
# 5244448                                        [Q18530304]
#
#                        date  numOccurrences  \
# 5000000 2020-03-06 17:20:36               3
# 5000001 2020-01-31 17:47:00               2
# 5000002 2020-03-26 19:43:00               1
# 5000003 2020-01-10 03:04:23               1
# 5000004 2020-04-02 12:27:27               2
# ...                     ...             ...
# 5244444 2020-02-24 05:00:28               1
# 5244445 2020-02-07 00:00:00               1
# 5244446 2020-02-27 05:59:00               1
# 5244447 2020-02-04 14:47:00              10
# 5244448 2020-02-24 04:30:00               3
#
#                                                     probas  \
# 5000000  5000000             [[Dave Marsden, 0.6329], [...
# 5000001  5000000             [[Dave Marsden, 0.6329], [...
# 5000002  5000000             [[Dave Marsden, 0.6329], [...
# 5000003  5000000             [[Dave Marsden, 0.6329], [...
# 5000004  5000000             [[Dave Marsden, 0.6329], [...
# ...                                                    ...
# 5244444  5000000             [[Dave Marsden, 0.6329], [...
# 5244445  5000000             [[Dave Marsden, 0.6329], [...
# 5244446  5000000             [[Dave Marsden, 0.6329], [...
# 5244447  5000000             [[Dave Marsden, 0.6329], [...
# 5244448  5000000             [[Dave Marsden, 0.6329], [...
#
#                                                       urls phase  \
# 5000000  [http://www.washingtontimes.com/news/2020/mar/...     E
# 5000001  [https://www.nbcnews.com/news/nbcblk/michelle-...     E
# 5000002  [http://capenews.net/sandwich/news/business-is...     E
# 5000003     [https://www.newkerala.com/news/2020/4460.htm]     E
# 5000004  [https://www.news18.com/news/world/alarm-denia...     E
# ...                                                    ...   ...
# 5244444  [http://feeds.browndailyherald.com/~r/BrownDai...     E
# 5244445  [https://www.villagevoice.com/2020/02/07/1980-...     E
# 5244446  [https://www.foxsports.com.au/nrl/nrl-premiers...     E
# 5244447  [http://timescolonist.com/in-the-rings-steski-...     E
# 5244448  [http://www.farmweekly.com.au/story/6646057/st...     E
#
#                                                     number
# 5000000  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000001  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000002  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000003  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000004  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# ...                                                    ...
# 5244444  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244445  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244446  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244447  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244448  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
#
# [244449 rows x 10 columns]

# %%
chunk.dtypes['probas']
# Out:
# dtype('O')

# %%
#chunk['probas']=str(chunk['probas'])

# %%
#import re
def find_number(text):
    num = re.findall(r'-?\d+\.?\d*',text)
    return " ".join(num)
chunk['number']=chunk['probas'].apply(lambda x: find_number(x))

#chunk['number']=chunk['probas'].str(apply(lambda x: re.findall(r'-?\d+\.?\d*',x)))#.to_frame()
#print(" ".join(chunk['number']))

# %%
chunk
# Out:
#                    quoteID                                          quotation  \
# 5000000  2020-03-06-047752  People get killed in wildlife collisions, most...
# 5000001  2020-01-31-070691  People my age and older have to figure out how...
# 5000002  2020-03-26-047932  People now have time on their hands and they w...
# 5000003  2020-01-10-061824  People should not recourse to violent methods ...
# 5000004  2020-04-02-047663  People think it's novel that 80-year-olds are ...
# ...                    ...                                                ...
# 5244444  2020-02-24-080186  you're seeing a young team that's maturing, th...
# 5244445  2020-02-07-122251  You're talking about African-Americans, right?...
# 5244446  2020-02-27-098715  You've got to own the team. I see Broosky and ...
# 5244447  2020-02-04-118820  You've got to sometimes take that leap of fait...
# 5244448  2020-02-24-080256  You've got to think that long term, it augurs ...
#
#                       speaker  \
# 5000000          Dave Marsden
# 5000001       Michelle Buteau
# 5000002             Gary Gray
# 5000003         Peter Machado
# 5000004         Candace Owens
# ...                       ...
# 5244444       Brendan Whittet
# 5244445  Barry Michael Cooper
# 5244446                  None
# 5244447           Brad Gushue
# 5244448           John Colley
#
#                                                       qids  \
# 5000000                                         [Q5240722]
# 5000001                                        [Q54861496]
# 5000002  [Q21228842, Q3758498, Q5525157, Q5525158, Q552...
# 5000003                                         [Q1385539]
# 5000004                                        [Q43302090]
# ...                                                    ...
# 5244444                                        [Q18115465]
# 5244445                                         [Q3635235]
# 5244446                                                 []
# 5244447                                          [Q896796]
# 5244448                                        [Q18530304]
#
#                        date  numOccurrences  \
# 5000000 2020-03-06 17:20:36               3
# 5000001 2020-01-31 17:47:00               2
# 5000002 2020-03-26 19:43:00               1
# 5000003 2020-01-10 03:04:23               1
# 5000004 2020-04-02 12:27:27               2
# ...                     ...             ...
# 5244444 2020-02-24 05:00:28               1
# 5244445 2020-02-07 00:00:00               1
# 5244446 2020-02-27 05:59:00               1
# 5244447 2020-02-04 14:47:00              10
# 5244448 2020-02-24 04:30:00               3
#
#                                                     probas  \
# 5000000  5000000             [[Dave Marsden, 0.6329], [...
# 5000001  5000000             [[Dave Marsden, 0.6329], [...
# 5000002  5000000             [[Dave Marsden, 0.6329], [...
# 5000003  5000000             [[Dave Marsden, 0.6329], [...
# 5000004  5000000             [[Dave Marsden, 0.6329], [...
# ...                                                    ...
# 5244444  5000000             [[Dave Marsden, 0.6329], [...
# 5244445  5000000             [[Dave Marsden, 0.6329], [...
# 5244446  5000000             [[Dave Marsden, 0.6329], [...
# 5244447  5000000             [[Dave Marsden, 0.6329], [...
# 5244448  5000000             [[Dave Marsden, 0.6329], [...
#
#                                                       urls phase  \
# 5000000  [http://www.washingtontimes.com/news/2020/mar/...     E
# 5000001  [https://www.nbcnews.com/news/nbcblk/michelle-...     E
# 5000002  [http://capenews.net/sandwich/news/business-is...     E
# 5000003     [https://www.newkerala.com/news/2020/4460.htm]     E
# 5000004  [https://www.news18.com/news/world/alarm-denia...     E
# ...                                                    ...   ...
# 5244444  [http://feeds.browndailyherald.com/~r/BrownDai...     E
# 5244445  [https://www.villagevoice.com/2020/02/07/1980-...     E
# 5244446  [https://www.foxsports.com.au/nrl/nrl-premiers...     E
# 5244447  [http://timescolonist.com/in-the-rings-steski-...     E
# 5244448  [http://www.farmweekly.com.au/story/6646057/st...     E
#
#                                                     number
# 5000000  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000001  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000002  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000003  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000004  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# ...                                                    ...
# 5244444  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244445  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244446  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244447  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244448  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
#
# [244449 rows x 10 columns]

# %%
chunk.drop(chunk[chunk['number'] < '0.9'].index)
# Out:
#                    quoteID                                          quotation  \
# 5000000  2020-03-06-047752  People get killed in wildlife collisions, most...
# 5000001  2020-01-31-070691  People my age and older have to figure out how...
# 5000002  2020-03-26-047932  People now have time on their hands and they w...
# 5000003  2020-01-10-061824  People should not recourse to violent methods ...
# 5000004  2020-04-02-047663  People think it's novel that 80-year-olds are ...
# ...                    ...                                                ...
# 5244444  2020-02-24-080186  you're seeing a young team that's maturing, th...
# 5244445  2020-02-07-122251  You're talking about African-Americans, right?...
# 5244446  2020-02-27-098715  You've got to own the team. I see Broosky and ...
# 5244447  2020-02-04-118820  You've got to sometimes take that leap of fait...
# 5244448  2020-02-24-080256  You've got to think that long term, it augurs ...
#
#                       speaker  \
# 5000000          Dave Marsden
# 5000001       Michelle Buteau
# 5000002             Gary Gray
# 5000003         Peter Machado
# 5000004         Candace Owens
# ...                       ...
# 5244444       Brendan Whittet
# 5244445  Barry Michael Cooper
# 5244446                  None
# 5244447           Brad Gushue
# 5244448           John Colley
#
#                                                       qids  \
# 5000000                                         [Q5240722]
# 5000001                                        [Q54861496]
# 5000002  [Q21228842, Q3758498, Q5525157, Q5525158, Q552...
# 5000003                                         [Q1385539]
# 5000004                                        [Q43302090]
# ...                                                    ...
# 5244444                                        [Q18115465]
# 5244445                                         [Q3635235]
# 5244446                                                 []
# 5244447                                          [Q896796]
# 5244448                                        [Q18530304]
#
#                        date  numOccurrences  \
# 5000000 2020-03-06 17:20:36               3
# 5000001 2020-01-31 17:47:00               2
# 5000002 2020-03-26 19:43:00               1
# 5000003 2020-01-10 03:04:23               1
# 5000004 2020-04-02 12:27:27               2
# ...                     ...             ...
# 5244444 2020-02-24 05:00:28               1
# 5244445 2020-02-07 00:00:00               1
# 5244446 2020-02-27 05:59:00               1
# 5244447 2020-02-04 14:47:00              10
# 5244448 2020-02-24 04:30:00               3
#
#                                                     probas  \
# 5000000  5000000             [[Dave Marsden, 0.6329], [...
# 5000001  5000000             [[Dave Marsden, 0.6329], [...
# 5000002  5000000             [[Dave Marsden, 0.6329], [...
# 5000003  5000000             [[Dave Marsden, 0.6329], [...
# 5000004  5000000             [[Dave Marsden, 0.6329], [...
# ...                                                    ...
# 5244444  5000000             [[Dave Marsden, 0.6329], [...
# 5244445  5000000             [[Dave Marsden, 0.6329], [...
# 5244446  5000000             [[Dave Marsden, 0.6329], [...
# 5244447  5000000             [[Dave Marsden, 0.6329], [...
# 5244448  5000000             [[Dave Marsden, 0.6329], [...
#
#                                                       urls phase  \
# 5000000  [http://www.washingtontimes.com/news/2020/mar/...     E
# 5000001  [https://www.nbcnews.com/news/nbcblk/michelle-...     E
# 5000002  [http://capenews.net/sandwich/news/business-is...     E
# 5000003     [https://www.newkerala.com/news/2020/4460.htm]     E
# 5000004  [https://www.news18.com/news/world/alarm-denia...     E
# ...                                                    ...   ...
# 5244444  [http://feeds.browndailyherald.com/~r/BrownDai...     E
# 5244445  [https://www.villagevoice.com/2020/02/07/1980-...     E
# 5244446  [https://www.foxsports.com.au/nrl/nrl-premiers...     E
# 5244447  [http://timescolonist.com/in-the-rings-steski-...     E
# 5244448  [http://www.farmweekly.com.au/story/6646057/st...     E
#
#                                                     number
# 5000000  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000001  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000002  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000003  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5000004  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# ...                                                    ...
# 5244444  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244445  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244446  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244447  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
# 5244448  5000000 0.6329 0.3671 5000001 0.8651 0.1349 50...
#
# [244449 rows x 10 columns]

# %%
chunk.dtypes['number']
# Out:
# dtype('O')

# %%
#chunk.drop(chunk[chunk['number'] < '0.9'].index)
