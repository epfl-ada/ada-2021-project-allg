# %% [markdown]
# # The evolution of the presence of women’s voices in the media
# Team ALLG : Amaia Soubelet, Lilian Haemmerli, Lucie Castella, Gabriel Juri

# %%
###Importing all the useful librairies

import time
import json
import bz2
import pandas as pd
import numpy as np
import re
from pathlib import Path
import matplotlib.pyplot as plt
import pyarrow as pa
import pyarrow.parquet as pq
import glob
import spacy
import os, codecs, random

from numpy.random import seed as random_seed
from numpy.random import shuffle as random_shuffle
seed = 42
random.seed(seed)
np.random.seed(seed)

# %% [markdown]
# ### Handling data

# %%
###  IMPORTING DATA ###

# Define the path where the data is located

Path = "../quotes-2020.json.bz2" #goes out of the current folder

# %% [markdown]
# To decrease the running time, we uploaded and filtered the different year's data one by one on different computers. Here is how it was done for the year 2020. We just changed the path and the name of the output cvs file for the different years. At the end of this document, you can see those cvs files being loaded and the result of each year pictured in pie charts.

# %%
#Filtering functions

def find_proba(text):
    num = re.findall(r'-?\d+\.?\d*',text)
    return " ".join(num)

def filter_speakers(chunk_data):

    chunk_data['probas'] = chunk_data['probas'].astype('str')
    chunk_data['number'] = chunk_data['probas'].apply(lambda x: find_proba(x)) #extracts the probability of the given speaker to be correct
    filt_low = chunk_data.drop(chunk_data[chunk_data['number'] < '0.9'].index) #removes lines with low probabilities to have the right speaker (less than 90%)
    filt_prob = filt_low.drop(filt_low[filt_low['speaker'] == 'None'].index) #removes the lines with no speaker
    return filt_prob

# %% [markdown]
# The two functions above are used to filter the data. Every quote that does not have a speaker (the speaker is 'None') is removed. We also filtered the quotes depending on the probability that the given speaker is the right one. Every quote with a speaker probability of less than 0.9 was removed. Since our work is studying the gender of the speaker, we needed to be sure that the speakers linked to the quotations are the real speakers.

# %%
def process_chunk(chunk):
        print(f'Processing chunk with {len(chunk)} rows')
        print(chunk.columns)

with pd.read_json(Path, lines=True, compression='bz2', chunksize=1_000_000) as df_reader:
    dfs = []
    for chunk in df_reader:
        process_chunk(chunk)        
        filt_chunk = filter_speakers(chunk) #filters the lines we want to remove
        dfs.append(filt_chunk)
# Out:
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 1000000 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')
# Processing chunk with 244449 rows
# Index(['quoteID', 'quotation', 'speaker', 'qids', 'date', 'numOccurrences',
#        'probas', 'urls', 'phase'],
#       dtype='object')

# %%
chunk.head() #not filtered --> to check the difference
# Out:
#                    quoteID                                          quotation  \
# 5000000  2020-03-06-047752  People get killed in wildlife collisions, most...
# 5000001  2020-01-31-070691  People my age and older have to figure out how...
# 5000002  2020-03-26-047932  People now have time on their hands and they w...
# 5000003  2020-01-10-061824  People should not recourse to violent methods ...
# 5000004  2020-04-02-047663  People think it's novel that 80-year-olds are ...
#
#                  speaker                                               qids  \
# 5000000     Dave Marsden                                         [Q5240722]
# 5000001  Michelle Buteau                                        [Q54861496]
# 5000002        Gary Gray  [Q21228842, Q3758498, Q5525157, Q5525158, Q552...
# 5000003    Peter Machado                                         [Q1385539]
# 5000004    Candace Owens                                        [Q43302090]
#
#                        date  numOccurrences  \
# 5000000 2020-03-06 17:20:36               3
# 5000001 2020-01-31 17:47:00               2
# 5000002 2020-03-26 19:43:00               1
# 5000003 2020-01-10 03:04:23               1
# 5000004 2020-04-02 12:27:27               2
#
#                                                     probas  \
# 5000000   [['Dave Marsden', '0.6329'], ['None', '0.3671']]
# 5000001  [['Michelle Buteau', '0.8651'], ['None', '0.13...
# 5000002      [['Gary Gray', '0.8611'], ['None', '0.1389']]
# 5000003  [['Peter Machado', '0.9013'], ['None', '0.0987']]
# 5000004  [['Candace Owens', '0.7324'], ['Anthony Fauci'...
#
#                                                       urls phase  \
# 5000000  [http://www.washingtontimes.com/news/2020/mar/...     E
# 5000001  [https://www.nbcnews.com/news/nbcblk/michelle-...     E
# 5000002  [http://capenews.net/sandwich/news/business-is...     E
# 5000003     [https://www.newkerala.com/news/2020/4460.htm]     E
# 5000004  [https://www.news18.com/news/world/alarm-denia...     E
#
#                               number
# 5000000                0.6329 0.3671
# 5000001                0.8651 0.1349
# 5000002                0.8611 0.1389
# 5000003                0.9013 0.0987
# 5000004  0.7324 0.1735 0.0903 0.0038

# %%
filt_chunk.head() #filtered
# Out:
#                    quoteID                                          quotation  \
# 5000003  2020-01-10-061824  People should not recourse to violent methods ...
# 5000016  2020-03-18-052109     Please stay away... while crews assess damage,
# 5000022  2020-01-24-066016  possibility of a heart bypass cannot be ruled out
# 5000033  2020-02-15-035807  Previously, many things were given flexibility...
# 5000035  2020-04-15-045130  Pritzker using a coronavirus briefing to campa...
#
#                                      speaker  \
# 5000003                        Peter Machado
# 5000016                         Gary Herbert
# 5000022  Victoria , Crown Princess of Sweden
# 5000033                  Eddin Syazlee Shith
# 5000035                        Tim Schneider
#
#                                       qids                date  \
# 5000003                         [Q1385539] 2020-01-10 03:04:23
# 5000016                          [Q881188] 2020-03-18 08:48:00
# 5000022                          [Q156390] 2020-01-24 18:54:14
# 5000033                        [Q55584836] 2020-02-15 16:24:42
# 5000035  [Q18745477, Q19663584, Q28466557] 2020-04-15 00:00:00
#
#          numOccurrences                                             probas  \
# 5000003               1  [['Peter Machado', '0.9013'], ['None', '0.0987']]
# 5000016               1   [['Gary Herbert', '0.9404'], ['None', '0.0596']]
# 5000022               5  [['Victoria , Crown Princess of Sweden', '0.90...
# 5000033               1  [['Eddin Syazlee Shith', '0.9581'], ['None', '...
# 5000035               1  [['Tim Schneider', '0.9489'], ['None', '0.0511']]
#
#                                                       urls phase  \
# 5000003     [https://www.newkerala.com/news/2020/4460.htm]     E
# 5000016  [https://www.cityweekly.net/BuzzBlog/archives/...     E
# 5000022  [https://www.geo.tv/latest/268956-nawaz-sharif...     E
# 5000033   [http://bernama.com/general/news.php?id=1814213]     E
# 5000035  [http://dailyherald.com/news/20200415/pritzker...     E
#
#                 number
# 5000003  0.9013 0.0987
# 5000016  0.9404 0.0596
# 5000022  0.9058 0.0942
# 5000033  0.9581 0.0419
# 5000035  0.9489 0.0511

# %%
pd.concat(dfs)
# Out:
#                    quoteID                                          quotation  \
# 7        2020-01-17-000357  [ The delay ] will have an impact [ on Slough ...
# 8        2020-04-02-000239  [ The scheme ] treats addiction as an illness ...
# 9        2020-03-19-000276  [ These ] actions will allow households who ha...
# 16       2020-01-08-000594                   11 straight weeks of pre-season,
# 19       2020-02-21-000455  2019 was a landmark year for Fiverr as we comp...
# ...                    ...                                                ...
# 5244412  2020-03-24-093541  You can't get social distance in a submarine a...
# 5244424  2020-03-28-040445                              You Know I' m No Good
# 5244435  2020-02-02-058890  You understood the structure of our story and ...
# 5244437  2020-01-28-115305  You'd probably be able to do that every now an...
# 5244448  2020-02-24-080256  You've got to think that long term, it augurs ...
#
#                  speaker                                               qids  \
# 7           Dexter Smith                                         [Q5268447]
# 8        Barry Coppinger                                         [Q4864119]
# 9             Ben Carson                                          [Q816459]
# 16        Aphelele Fassi                                        [Q56255401]
# 19         Micha Kaufman                                        [Q26923564]
# ...                  ...                                                ...
# 5244412       Mark Esper                                        [Q33190271]
# 5244424    Amy Winehouse                                           [Q15897]
# 5244435     Bong Joon Ho                                          [Q495980]
# 5244437  Michael Maguire  [Q3856214, Q4274205, Q42887501, Q6832442, Q683...
# 5244448      John Colley                                        [Q18530304]
#
#                        date  numOccurrences  \
# 7       2020-01-17 13:03:00               1
# 8       2020-04-02 14:18:20               1
# 9       2020-03-19 19:14:00               1
# 16      2020-01-08 10:22:11               1
# 19      2020-02-21 13:00:00               1
# ...                     ...             ...
# 5244412 2020-03-24 22:32:54               1
# 5244424 2020-03-28 17:00:40               1
# 5244435 2020-02-02 08:27:01               4
# 5244437 2020-01-28 23:26:18               1
# 5244448 2020-02-24 04:30:00               3
#
#                                                     probas  \
# 7           [['Dexter Smith', '0.924'], ['None', '0.076']]
# 8        [['Barry Coppinger', '0.9017'], ['None', '0.09...
# 9           [['Ben Carson', '0.9227'], ['None', '0.0773']]
# 16       [['Aphelele Fassi', '0.9033'], ['None', '0.096...
# 19       [['Micha Kaufman', '0.9409'], ['None', '0.0591']]
# ...                                                    ...
# 5244412     [['Mark Esper', '0.9434'], ['None', '0.0566']]
# 5244424  [['Amy Winehouse', '0.9469'], ['None', '0.0477...
# 5244435  [['Bong Joon Ho', '0.9476'], ['None', '0.0454'...
# 5244437  [['Michael Maguire', '0.9191'], ['None', '0.08...
# 5244448      [['John Colley', '0.928'], ['None', '0.072']]
#
#                                                       urls phase  \
# 7        [http://www.sloughexpress.co.uk/gallery/slough...     E
# 8        [http://www.theweek.co.uk/106479/why-police-ar...     E
# 9        [https://mortgageorb.com/hud-fha-suspend-forec...     E
# 16       [https://www.sport24.co.za/Rugby/SuperRugby/sh...     E
# 19       [https://www.fool.com/investing/2020/02/21/why...     E
# ...                                                    ...   ...
# 5244412  [https://news.usni.org/2020/03/24/navy-adapts-...     E
# 5244424  [https://www.goldderby.com/article/2020/the-ma...     E
# 5244435  [https://www.prokerala.com/news/articles/a1003...     E
# 5244437  [http://www.nrl.com/news/2020/01/29/tigers-and...     E
# 5244448  [http://www.farmweekly.com.au/story/6646057/st...     E
#
#                                            number
# 7                                     0.924 0.076
# 8                                   0.9017 0.0983
# 9                                   0.9227 0.0773
# 16                                  0.9033 0.0967
# 19                                  0.9409 0.0591
# ...                                           ...
# 5244412                             0.9434 0.0566
# 5244424        0.9469 0.0477 0.0021 0.0019 0.0014
# 5244435  0.9476 0.0454 0.004 0.0015 8.0 -4 7.0 -4
# 5244437                             0.9191 0.0809
# 5244448                               0.928 0.072
#
# [701514 rows x 10 columns]

# %%
df = pd.concat(dfs)
df['qids'] = df['qids'].str[0]

# %% [markdown]
# ### Adding the .parquet database given

# %%
### NO NEED TO RUN AGAIN!!
### Merging and importing parquet files into csv

from pathlib import Path

data_dir = Path('C:/data/speaker_attributes.parquet')
for i, parquet_path in enumerate(data_dir.glob('*.parquet')):
    df = pd.read_parquet(parquet_path)
    write_header = i == 0 # write header only on the 0th file
    write_mode = 'w' if i == 0 else 'a' # 'write' mode for 0th file, 'append' otherwise
    df.to_csv('featuresQID.csv', mode=write_mode, header=write_header)

# %%
### Merging qotes and gender charateristic of each speaker 

featuresQID = pd.read_csv('featuresQID.csv',low_memory=False)
featuresQID
#featuresQID = featuresQID.rename(columns = {'id':'qids'})
#dff = pd.merge(df,featuresQID[['qids','gender']],on='qids', how='left')
# Out:
#          Unnamed: 0                                            aliases  \
# 0                 0  ['Washington' 'President Washington' 'G. Washi...
# 1                 1  ['Douglas Noel Adams' 'Douglas Noël Adams' 'Do...
# 2                 2   ['Paul Marie Ghislain Otlet' 'Paul Marie Otlet']
# 3                 3  ['George Walker Bush' 'Bush Jr.' 'Dubya' 'GWB'...
# 4                 4  ['Velázquez' 'Diego Rodríguez de Silva y Veláz...
# ...             ...                                                ...
# 9055976      639477                                  ['Barker Howard']
# 9055977      639478                               ['Charles Macomber']
# 9055978      639479                                                NaN
# 9055979      639480                                                NaN
# 9055980      639481                                     ['Fred Trull']
#
#                      date_of_birth        nationality        gender  \
# 0        ['+1732-02-22T00:00:00Z']  ['Q161885' 'Q30']  ['Q6581097']
# 1        ['+1952-03-11T00:00:00Z']           ['Q145']  ['Q6581097']
# 2        ['+1868-08-23T00:00:00Z']            ['Q31']  ['Q6581097']
# 3        ['+1946-07-06T00:00:00Z']            ['Q30']  ['Q6581097']
# 4        ['+1599-06-06T00:00:00Z']            ['Q29']  ['Q6581097']
# ...                            ...                ...           ...
# 9055976                        NaN            ['Q30']  ['Q6581097']
# 9055977                        NaN            ['Q30']  ['Q6581097']
# 9055978  ['+1848-04-01T00:00:00Z']                NaN  ['Q6581072']
# 9055979  ['+1899-03-18T00:00:00Z']                NaN  ['Q6581072']
# 9055980                        NaN            ['Q30']  ['Q6581097']
#
#           lastrevid  ethnic_group US_congress_bio_ID  \
# 0        1395141751           NaN            W000178
# 1        1395737157  ['Q7994501']                NaN
# 2        1380367296           NaN                NaN
# 3        1395142029           NaN                NaN
# 4        1391704596           NaN                NaN
# ...             ...           ...                ...
# 9055976  1397399351           NaN                NaN
# 9055977  1397399471           NaN                NaN
# 9055978  1397399751           NaN                NaN
# 9055979  1397399799           NaN                NaN
# 9055980  1397400809           NaN                NaN
#
#                                                 occupation        party  \
# 0        ['Q82955' 'Q189290' 'Q131512' 'Q1734662' 'Q294...  ['Q327591']
# 1        ['Q214917' 'Q28389' 'Q6625963' 'Q4853732' 'Q18...          NaN
# 2        ['Q36180' 'Q40348' 'Q182436' 'Q1265807' 'Q2053...          NaN
# 3        ['Q82955' 'Q15982858' 'Q18814623' 'Q1028181' '...   ['Q29468']
# 4                                             ['Q1028181']          NaN
# ...                                                    ...          ...
# 9055976                                         ['Q82955']          NaN
# 9055977                                         ['Q82955']          NaN
# 9055978                                                NaN          NaN
# 9055979                                                NaN          NaN
# 9055980                                         ['Q82955']          NaN
#
#         academic_degree          id                label  \
# 0                   NaN         Q23    George Washington
# 1                   NaN         Q42        Douglas Adams
# 2                   NaN       Q1868           Paul Otlet
# 3                   NaN        Q207       George W. Bush
# 4                   NaN        Q297      Diego Velázquez
# ...                 ...         ...                  ...
# 9055976             NaN  Q106406560     Barker B. Howard
# 9055977             NaN  Q106406571  Charles H. Macomber
# 9055978             NaN  Q106406588           Dina David
# 9055979             NaN  Q106406593        Irma Dexinger
# 9055980             NaN  Q106406643        Fred F. Trull
#
#                                            candidacy  type  \
# 0                              ['Q698073' 'Q697949']  item
# 1                                                NaN  item
# 2                                                NaN  item
# 3        ['Q327959' 'Q464075' 'Q3586276' 'Q4450587']  item
# 4                                                NaN  item
# ...                                              ...   ...
# 9055976                                          NaN  item
# 9055977                                          NaN  item
# 9055978                                          NaN  item
# 9055979                                          NaN  item
# 9055980                                          NaN  item
#
#                                religion
# 0                           ['Q682443']
# 1                                   NaN
# 2                                   NaN
# 3        ['Q329646' 'Q682443' 'Q33203']
# 4                                   NaN
# ...                                 ...
# 9055976                             NaN
# 9055977                             NaN
# 9055978                             NaN
# 9055979                             NaN
# 9055980                             NaN
#
# [9055981 rows x 16 columns]

# %%
featuresQID = featuresQID.rename(columns = {'id':'qids'})
featuresQID
# Out:
#          Unnamed: 0                                            aliases  \
# 0                 0  ['Washington' 'President Washington' 'G. Washi...
# 1                 1  ['Douglas Noel Adams' 'Douglas Noël Adams' 'Do...
# 2                 2   ['Paul Marie Ghislain Otlet' 'Paul Marie Otlet']
# 3                 3  ['George Walker Bush' 'Bush Jr.' 'Dubya' 'GWB'...
# 4                 4  ['Velázquez' 'Diego Rodríguez de Silva y Veláz...
# ...             ...                                                ...
# 9055976      639477                                  ['Barker Howard']
# 9055977      639478                               ['Charles Macomber']
# 9055978      639479                                                NaN
# 9055979      639480                                                NaN
# 9055980      639481                                     ['Fred Trull']
#
#                      date_of_birth        nationality        gender  \
# 0        ['+1732-02-22T00:00:00Z']  ['Q161885' 'Q30']  ['Q6581097']
# 1        ['+1952-03-11T00:00:00Z']           ['Q145']  ['Q6581097']
# 2        ['+1868-08-23T00:00:00Z']            ['Q31']  ['Q6581097']
# 3        ['+1946-07-06T00:00:00Z']            ['Q30']  ['Q6581097']
# 4        ['+1599-06-06T00:00:00Z']            ['Q29']  ['Q6581097']
# ...                            ...                ...           ...
# 9055976                        NaN            ['Q30']  ['Q6581097']
# 9055977                        NaN            ['Q30']  ['Q6581097']
# 9055978  ['+1848-04-01T00:00:00Z']                NaN  ['Q6581072']
# 9055979  ['+1899-03-18T00:00:00Z']                NaN  ['Q6581072']
# 9055980                        NaN            ['Q30']  ['Q6581097']
#
#           lastrevid  ethnic_group US_congress_bio_ID  \
# 0        1395141751           NaN            W000178
# 1        1395737157  ['Q7994501']                NaN
# 2        1380367296           NaN                NaN
# 3        1395142029           NaN                NaN
# 4        1391704596           NaN                NaN
# ...             ...           ...                ...
# 9055976  1397399351           NaN                NaN
# 9055977  1397399471           NaN                NaN
# 9055978  1397399751           NaN                NaN
# 9055979  1397399799           NaN                NaN
# 9055980  1397400809           NaN                NaN
#
#                                                 occupation        party  \
# 0        ['Q82955' 'Q189290' 'Q131512' 'Q1734662' 'Q294...  ['Q327591']
# 1        ['Q214917' 'Q28389' 'Q6625963' 'Q4853732' 'Q18...          NaN
# 2        ['Q36180' 'Q40348' 'Q182436' 'Q1265807' 'Q2053...          NaN
# 3        ['Q82955' 'Q15982858' 'Q18814623' 'Q1028181' '...   ['Q29468']
# 4                                             ['Q1028181']          NaN
# ...                                                    ...          ...
# 9055976                                         ['Q82955']          NaN
# 9055977                                         ['Q82955']          NaN
# 9055978                                                NaN          NaN
# 9055979                                                NaN          NaN
# 9055980                                         ['Q82955']          NaN
#
#         academic_degree        qids                label  \
# 0                   NaN         Q23    George Washington
# 1                   NaN         Q42        Douglas Adams
# 2                   NaN       Q1868           Paul Otlet
# 3                   NaN        Q207       George W. Bush
# 4                   NaN        Q297      Diego Velázquez
# ...                 ...         ...                  ...
# 9055976             NaN  Q106406560     Barker B. Howard
# 9055977             NaN  Q106406571  Charles H. Macomber
# 9055978             NaN  Q106406588           Dina David
# 9055979             NaN  Q106406593        Irma Dexinger
# 9055980             NaN  Q106406643        Fred F. Trull
#
#                                            candidacy  type  \
# 0                              ['Q698073' 'Q697949']  item
# 1                                                NaN  item
# 2                                                NaN  item
# 3        ['Q327959' 'Q464075' 'Q3586276' 'Q4450587']  item
# 4                                                NaN  item
# ...                                              ...   ...
# 9055976                                          NaN  item
# 9055977                                          NaN  item
# 9055978                                          NaN  item
# 9055979                                          NaN  item
# 9055980                                          NaN  item
#
#                                religion
# 0                           ['Q682443']
# 1                                   NaN
# 2                                   NaN
# 3        ['Q329646' 'Q682443' 'Q33203']
# 4                                   NaN
# ...                                 ...
# 9055976                             NaN
# 9055977                             NaN
# 9055978                             NaN
# 9055979                             NaN
# 9055980                             NaN
#
# [9055981 rows x 16 columns]

# %%
dff = pd.merge(df,featuresQID[['qids','gender','ethnic_group','occupation','academic_degree','nationality','date_of_birth']],on='qids', how='left')

# %%
dff['gender'].value_counts()
# Out:
# ['Q6581097']                         575817
# ['Q6581072']                         111093
# ['Q1052281']                            504
# ['Q48270']                              242
# ['Q18116794']                            88
# ['Q2449503']                             67
# ['Q6581097' 'Q179294']                   42
# ['Q48270' 'Q6581072']                    23
# ['Q1984232']                             21
# ['Q6581072' 'Q48270']                    18
# ['Q15145778']                            15
# ['Q6581097' 'Q189125']                   14
# ['Q15145779']                            10
# ['Q12964198']                             6
# ['Q1097630' 'Q48270']                     5
# ['Q27679766' 'Q859614']                   4
# ['Q48270' 'Q12964198']                    4
# ['Q15145779' 'Q1097630']                  4
# ['Q6581097' 'Q6581072']                   3
# ['Q6581072' 'Q6581097']                   2
# ['Q48270' 'Q189125']                      2
# ['Q1289754']                              1
# ['Q2449503' 'Q48270' 'Q12964198']         1
# ['Q1052281' 'Q6581097']                   1
# ['Q48279']                                1
# ['Q6581072' 'Q3277905']                   1
# ['Q6581097' 'Q1097630']                   1
# ['Q6581097' 'Q18116794']                  1
# Name: gender, dtype: int64

# %% [markdown]
# ### Counting gender proportions

# %%
def gender(x):
    
    'Function to convert wikidata id into a gender string value'
    'We consider male and female as male/female and transgender male/female respectly'

    if x == "['Q6581097']" or x =="['Q2449503']": #males and transgender males
        return 'male'
    elif x == "['Q6581072']" or  x ==  "['Q1052281']": #females and transgender females
        return 'female'
    elif pd.isna(x):
        return np.nan
    else:
        return 'other'

dff['gen'] = dff['gender'].apply(gender)
dff['gen'].value_counts(dropna=False)
# Out:
# male      575884
# female    111597
# NaN        13523
# other        510
# Name: gen, dtype: int64

# %%
import pickle
path ='gen_2020.pickle'
# Store data (serialize)
with open(path, 'wb') as handle:
    pickle.dump(dff[['qids','quoteID','gen']], handle, protocol=pickle.HIGHEST_PROTOCOL)

dff[['qids','quoteID','gen']]
pd.DataFrame.from_dict(data=dff[['qids','quoteID','gen']], orient='columns').to_csv("gen_2020.csv", header=False)

# %%
pd.DataFrame.from_dict(data=dff[['qids','quoteID','gen','quotation','ethnic_group','occupation','academic_degree','nationality','date_of_birth']], orient='columns').to_csv("fin_2019.csv", header=False)

# %% [markdown]
# ### A first glance to the data:
# cvs files of every year (that were generated one by one on our different computers using the code above) are now being loaded and presented in graphs.

# %%
# load the csv files with the gender information of all the years into one dataframe
# set the header

gen15 = pd.read_csv('gen_2015.csv', header = None, index_col=False)
gen16 = pd.read_csv('gen_2016.csv', header = None, index_col=False)
gen17 = pd.read_csv('gen_2017.csv', header = None, index_col=False)
gen18 = pd.read_csv('gen_2018.csv', header = None, index_col=False)
gen19 = pd.read_csv('gen_2019.csv', header = None, index_col=False)
gen20 = pd.read_csv('gen_2020.csv', header = None, index_col=False)

df = gen15.append([gen16,gen17,gen18,gen19,gen20])
df.rename(columns={1: 'qids', 2: 'Date', 3: 'Gender'}, inplace=True)
df.head()
# Out:
#    0       qids               Date  Gender
# 0  0   Q5107822  2015-03-22-011043    male
# 1  1  Q42969376  2015-07-22-000568  female
# 2  2   Q7199798  2015-03-26-025269    male
# 3  3  Q29654671  2015-08-12-028781    male
# 4  4   Q7356142  2015-12-24-000354    male

# %%
# split the date column into different columns to get rid of the last 7 characters (minutes and seconds)

df[['Year','Month','Day','Secs']] = df.Date.str.split("-",expand=True)
df.head()
# Out:
#    0       qids               Date  Gender  Year Month Day    Secs
# 0  0   Q5107822  2015-03-22-011043    male  2015    03  22  011043
# 1  1  Q42969376  2015-07-22-000568  female  2015    07  22  000568
# 2  2   Q7199798  2015-03-26-025269    male  2015    03  26  025269
# 3  3  Q29654671  2015-08-12-028781    male  2015    08  12  028781
# 4  4   Q7356142  2015-12-24-000354    male  2015    12  24  000354

# %%
# set all the values of the day column to 15
# so that we can plot the percentage per month more easily

df.Day=15
df
# Out:
#              0       qids               Date  Gender  Year Month  Day    Secs
# 0            0   Q5107822  2015-03-22-011043    male  2015    03   15  011043
# 1            1  Q42969376  2015-07-22-000568  female  2015    07   15  000568
# 2            2   Q7199798  2015-03-26-025269    male  2015    03   15  025269
# 3            3  Q29654671  2015-08-12-028781    male  2015    08   15  028781
# 4            4   Q7356142  2015-12-24-000354    male  2015    12   15  000354
# ...        ...        ...                ...     ...   ...   ...  ...     ...
# 701509  701509  Q33190271  2020-03-24-093541    male  2020    03   15  093541
# 701510  701510     Q15897  2020-03-28-040445  female  2020    03   15  040445
# 701511  701511    Q495980  2020-02-02-058890    male  2020    02   15  058890
# 701512  701512   Q3856214  2020-01-28-115305    male  2020    01   15  115305
# 701513  701513  Q18530304  2020-02-24-080256    male  2020    02   15  080256
#
# [14517825 rows x 8 columns]

# %%
# drop the columns not needed anymore

df=df.drop(columns=['Secs', 'Date'])

# create the new date column without the "minutes and seconds"

df['Date'] = df['Day'].map(str) + '-' + df['Month'].map(str) + '-' + df['Year'].map(str)
df.head()

# drop all the rows that contain NaN

df=df.dropna()

# %%
# convert the date column into a datetime object

df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#    0       qids  Gender  Year Month  Day       Date
# 0  0   Q5107822    male  2015    03   15 2015-03-15
# 1  1  Q42969376  female  2015    07   15 2015-07-15
# 2  2   Q7199798    male  2015    03   15 2015-03-15
# 3  3  Q29654671    male  2015    08   15 2015-08-15
# 4  4   Q7356142    male  2015    12   15 2015-12-15

# %%
# convert the date column to an index

df.index = df['Date']
del df['Date']
print(df.head())
# Out:
#             0       qids  Gender  Year Month  Day
# Date
# 2015-03-15  0   Q5107822    male  2015    03   15
# 2015-07-15  1  Q42969376  female  2015    07   15
# 2015-03-15  2   Q7199798    male  2015    03   15
# 2015-08-15  3  Q29654671    male  2015    08   15
# 2015-12-15  4   Q7356142    male  2015    12   15

# %%
# groupby to get the number of speaker per gender and month

df1 = df.groupby(['Gender', 'Date', 'Year', 'Month']).size().reset_index(name='counts')
df1
# Out:
#      Gender       Date  Year Month  counts
# 0    female 2015-01-15  2015    01   25395
# 1    female 2015-02-15  2015    02   26293
# 2    female 2015-03-15  2015    03   29956
# 3    female 2015-04-15  2015    04   23872
# 4    female 2015-05-15  2015    05   18084
# ..      ...        ...   ...   ...     ...
# 187   other 2019-12-15  2019    12     143
# 188   other 2020-01-15  2020    01     150
# 189   other 2020-02-15  2020    02     140
# 190   other 2020-03-15  2020    03     161
# 191   other 2020-04-15  2020    04      59
#
# [192 rows x 5 columns]

# %%
### Chart of all years together --> mean

male = df[df['Gender'] == 'male'].Gender.count()
female = df[df['Gender'] == 'female'].Gender.count()
other = df[df['Gender'] == 'other'].Gender.count()
total = male + female + other
# import the pyplot library

import matplotlib.pyplot as plotter

# The slice names of a population distribution pie chart
labels = ['male','female','other']

# Population data
sizes = [male/total, female/total, other/total]
figureObject, axesObject = plotter.subplots()

# Draw the pie chart

axesObject.pie(sizes,
    labels=labels,
    autopct='%1.1f%%',
    startangle=170,
    colors = ['#d01c8b', '#b8e186', '#f1b6da'])

# Aspect ratio - equal means pie is a circle

axesObject.axis('equal')
plt.title('Proportion of speakers regarding the gender for years 2015 to 2020', fontsize = 14);
plotter.show()

# %%
# Cheking the extact proportion by year and gender

data2 = pd.DataFrame(pd.crosstab(df.index.year, df.Gender,normalize='index').mul(100))
data2
# Out:
# Gender     female       male     other
# row_0
# 2015    12.675889  87.247172  0.076939
# 2016    13.412064  86.525504  0.062433
# 2017    13.970023  85.949300  0.080677
# 2018    14.893490  85.023715  0.082795
# 2019    15.710181  84.200842  0.088977
# 2020    16.220706  83.705165  0.074129

# %%
# Plotting gender proportion by year
import seaborn as sns

ax = data2.plot.bar(stacked=False, color=['#b8e186', '#d01c8b', '#f1b6da'])

for container in ax.containers:          # loop to consider the gender percentage in each year
    ax.bar_label(container,fmt='%.1f')
    
plt.xticks(rotation=20);
plt.xlabel('Year');
plt.ylabel('Proportion');
plt.title('Gender proportion by year');
plt.savefig('eachyears',facecolor = 'w')

# %% [markdown]
# # Testing if there exist a differnce in the propotion of woman as speaker through the time

# %% [markdown]
# ### Is there a significant difference between the proportion of womens as speakers before and after 2017 (Mee two Movement)?

# %%
before = pd.DataFrame(df[df.index.year <= 2015].Gender.value_counts()).rename(columns={'Gender': 'before'})
after =  pd.DataFrame(df[df.index.year  >= 2020].Gender.value_counts()).rename(columns={'Gender': 'after'})

beaf = pd.concat([before,after],axis = 1)

# For normal distributed data
def comparing_two_proportions (p1,p2,n1,n2):
   
    '''
           Function to compare if two proportion are different.
    
    *   Significance level -ref- = 0.05
    *   Proportion of the first group = p1
    *   Size of the first group = n1
    *   Proportion of the second group = p2
    *   Size of the second group = n2
    '''
    
    ref = 1.96
    p = (n1*p1+n2*p2)/(n1+n2)
    n1n2 = (1/n1)+(1/n2)
    z = (p1-p2)/np.sqrt(p*(1-p)*n1n2)
    
    if -ref<z<ref:
        print('No statisttical difference')
   
    elif -ref>z:
        print(f'Since Zscore is lower than {-ref} the null hypothesis is rejected, and therefore there is a significan difference')     
    else: 
        print(f'Since Zscore is higher than {ref} the null hypothesis is rejected, and therefore there is a significan difference')

comparing_two_proportions (0.139700,0.162207,3226430,687991);
# Out:
# Since Zscore is lower than -1.96 the null hypothesis is rejected, and therefore there is a significan difference

# %% [markdown]
# ### Is there a significant difference between the proportion of womens as speakers between 2017 and 2020 ?

# %%
prp_2017 = pd.DataFrame(df[df.index.year == 2017].Gender.value_counts(normalize = True)).rename(columns={'Gender': '2017'})
prp_2020 =  pd.DataFrame(df[df.index.year == 2020].Gender.value_counts(normalize = True)).rename(columns={'Gender': '2017'})

beaf = pd.concat([prp_2017,prp_2020],axis = 1)

comparing_two_proportions (0.1397,0.162207,450733,111597)
# Out:
# Since Zscore is lower than -1.96 the null hypothesis is rejected, and therefore there is a significan difference

# %% [markdown]
# # Time Series Analysis of female speaker percentage

# %% [markdown]
# ### Time series plot

# %%
# change structure of the dataframe 

df2=df1.pivot(index=['Date','Year','Month'], columns='Gender', values='counts') # for linear regression 
df3=df1.pivot(index=['Date'], columns='Gender', values='counts') # to check for stationarity

# %%
# calculate the percentage of female speaker per month 
# by diving the amount of female speakers by the total amount of speakers

df2['perc_fem'] = df2.female/(df2.female+df2.male+df2.other)
df3['perc_fem'] = df3.female/(df3.female+df3.male+df3.other)
df2.head()
# Out:
# Gender                 female    male  other  perc_fem
# Date       Year Month
# 2015-01-15 2015 01      25395  184035    153  0.121169
# 2015-02-15 2015 02      26293  183104    181  0.125457
# 2015-03-15 2015 03      29956  209105    120  0.125244
# 2015-04-15 2015 04      23872  164781     64  0.126496
# 2015-05-15 2015 05      18084  124481     96  0.126762

# %%
# plot the time series over months
import seaborn as sns

p = sns.lineplot(data=df2, x="Date", y="perc_fem")
p.set_xlabel("Year", fontsize = 12)
p.set_ylabel("Percentage of female speaker", fontsize = 12);

# %%
# make subsets per year and plot them

perc_2015 = df2['2015-01-15':'2015-12-15']
perc_2016 = df2['2016-01-15':'2016-12-15']
perc_2017 = df2['2017-01-15':'2017-12-15']
perc_2018 = df2['2018-01-15':'2018-12-15']
perc_2019 = df2['2019-01-15':'2019-12-15']
perc_2020 = df2['2020-01-15':'2020-04-15']

fig, axes = plt.subplots(3,2, figsize=(10, 10))
fig.suptitle('Female speaker percentage per year')


sns.lineplot(ax=axes[0,0], data=perc_2015, x="Month", y="perc_fem").set(ylabel="Percentage of female speaker", xlabel='2015')
sns.lineplot(ax=axes[0,1], data=perc_2016, x="Month", y="perc_fem").set(ylabel="Percentage of female speaker", xlabel='2016')
sns.lineplot(ax=axes[1,0], data=perc_2017, x="Month", y="perc_fem").set(ylabel="Percentage of female speaker", xlabel='2017')
sns.lineplot(ax=axes[1,1], data=perc_2018, x="Month", y="perc_fem").set(ylabel="Percentage of female speaker", xlabel='2018')
sns.lineplot(ax=axes[2,0], data=perc_2019, x="Month", y="perc_fem").set(ylabel="Percentage of female speaker", xlabel='2019')
sns.lineplot(ax=axes[2,1], data=perc_2020, x="Month", y="perc_fem").set(ylabel="Percentage of female speaker", xlabel='2020')

fig.tight_layout(pad=3.0);

# %% [markdown]
# ### Trend detection by shuffling percentage values

# %%
# time series plot by shuffling of percentage values
# this is how plot would look like if no there is no trend
# several shuffling plots were created to compare with the original plot

dfshuf = df2.copy()
dfshuf['perc_fem'] = df2.perc_fem.sample(frac=1).values
sns.lineplot(data=dfshuf, x="Date", y="perc_fem");

# %% [markdown]
# ### Trend detection by performing rolling average

# %%
# drop columns not needed anymore

df3=df3.drop(columns=['female', 'male','other'])

# %%
# perform rolling average of the data

rolling_mean = df3.rolling(7).mean()
rolling_std = df3.rolling(7).std()

# %%
# plotting the results of the rolling

plt.plot(df3, color="blue", label="Original percentage of female speaker")
plt.plot(rolling_mean, color="red", label="Rolling Mean female percentage")
plt.plot(rolling_std, color="black", label = "Rolling Standard Deviation female percentage");

# %% [markdown]
# ### Trend detection with the Dickey Fuller test

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

from statsmodels.tsa.stattools import adfuller

adft = adfuller(df3, autolag="AIC")

# %%
output_df = pd.DataFrame({"Values":
                         [adft[0], adft[1], adft[2], adft[3], adft[4]['1%'],
                          adft[4]['5%'], adft[4]['10%']] , 
                          "Metric":
                          ["Test Statistics", "p-value", "No. of lags used", 
                           "Number of observations used", 
                           "critical value (1%)",
                           "critical value (5%)",
                         "critical value (10%)"]})

print(output_df)
# Out:
#       Values                       Metric
# 0  -0.597911              Test Statistics
# 1   0.871453                      p-value
# 2   6.000000             No. of lags used
# 3  57.000000  Number of observations used
# 4  -3.550670          critical value (1%)
# 5  -2.913766          critical value (5%)
# 6  -2.594624         critical value (10%)

# %% [markdown]
# p-value > 0.05 and therefore the null hypothesis (data non-stationary) is not being rejected.

# %% [markdown]
# ### Trend calculation with Linear regression

# %%
# for linear regression, date column needs to be non-index

df25 = df2.reset_index()
df25
# Out:
# Gender       Date  Year Month  female    male  other  perc_fem
# 0      2015-01-15  2015    01   25395  184035    153  0.121169
# 1      2015-02-15  2015    02   26293  183104    181  0.125457
# 2      2015-03-15  2015    03   29956  209105    120  0.125244
# 3      2015-04-15  2015    04   23872  164781     64  0.126496
# 4      2015-05-15  2015    05   18084  124481     96  0.126762
# ..            ...   ...   ...     ...     ...    ...       ...
# 59     2019-12-15  2019    12   30890  167114    143  0.155894
# 60     2020-01-15  2020    01   33964  179514    150  0.158987
# 61     2020-02-15  2020    02   32522  168681    140  0.161525
# 62     2020-03-15  2020    03   30883  157731    161  0.163597
# 63     2020-04-15  2020    04   14228   69958     59  0.168888
#
# [64 rows x 7 columns]

# %%
# to create the x axis for the linear regression plot
# where the numbers stand for the years starting by 2015

df25['x'] = df25['Year'].astype('int64') - 2015 + df25['Month'].astype('int64')/12 - 1/24
df25
# Out:
# Gender       Date  Year Month  female    male  other  perc_fem         x
# 0      2015-01-15  2015    01   25395  184035    153  0.121169  0.041667
# 1      2015-02-15  2015    02   26293  183104    181  0.125457  0.125000
# 2      2015-03-15  2015    03   29956  209105    120  0.125244  0.208333
# 3      2015-04-15  2015    04   23872  164781     64  0.126496  0.291667
# 4      2015-05-15  2015    05   18084  124481     96  0.126762  0.375000
# ..            ...   ...   ...     ...     ...    ...       ...       ...
# 59     2019-12-15  2019    12   30890  167114    143  0.155894  4.958333
# 60     2020-01-15  2020    01   33964  179514    150  0.158987  5.041667
# 61     2020-02-15  2020    02   32522  168681    140  0.161525  5.125000
# 62     2020-03-15  2020    03   30883  157731    161  0.163597  5.208333
# 63     2020-04-15  2020    04   14228   69958     59  0.168888  5.291667
#
# [64 rows x 8 columns]

# %%
# plotting the linear regression

sns.regplot(x="x", y="perc_fem", data=df25, ci=None);

# %%
# reshaping the percentage and x axis column to calculate the slope

pf = df25.perc_fem.values.reshape(-1,1)
x = df25.x.values.reshape(-1,1)

# %%
# do linear regression to calculate the slope -> increase 

import numpy as np
from sklearn.linear_model import LinearRegression

reg = LinearRegression().fit(x, pf)
reg.coef_
# Out:
# array([[0.00676485]])

# %% [markdown]
# The linear regression indicates that the percentage of female speaker increases by 0.68% per year.

# %% [markdown]
# ### Check for seasonality

# %%
# check for seasonality by plotting data per month

sns.scatterplot(x="Month", y="perc_fem", data=df25);

# %% [markdown]
# The scatterplot above shows the percentage of female speaker per month of all the year and indicates that there is no seasonality (no trend) in the data.

# %% [markdown]
# ### Analysis of quotes

# %%
df = pd.read_csv("fin_2020.csv")

# %%
df.head(10)
# Out:
#     0   Q5268447  2020-01-17-000357    male  \
# 0   1   Q4864119  2020-04-02-000239    male
# 1   2    Q816459  2020-03-19-000276    male
# 2   3  Q56255401  2020-01-08-000594    male
# 3   4  Q26923564  2020-02-21-000455    male
# 4   5   Q4749380  2020-04-01-000532  female
# 5   6   Q5106592  2020-01-29-001076    male
# 6   7    Q771586  2020-01-26-000499    male
# 7   8  Q16195572  2020-02-29-000491    male
# 8   9   Q7322163  2020-03-23-000896  female
# 9  10  Q18151420  2020-01-10-001448    male
#
#   [ The delay ] will have an impact [ on Slough ] but that might be mitigated by the fact we are going to have this Western Rail Link to Heathrow. It looks like that may come in sooner than Crossrail.  \
# 0  [ The scheme ] treats addiction as an illness ...
# 1  [ These ] actions will allow households who ha...
# 2                   11 straight weeks of pre-season,
# 3  2019 was a landmark year for Fiverr as we comp...
# 4  7pm is when most hospitals change shifts. That...
# 5  A collaborative opioid stewardship program, ac...
# 6  a few of the candidates who will do better in ...
# 7         a lack of resources and government funding
# 8  A little over a week old. Thankful for God's g...
# 9           a lot of contacts and a lot of knowledge
#
#                Unnamed: 5                                      ['Q12299841']  \
# 0                     NaN                                                NaN
# 1              ['Q49085']  ['Q212980' 'Q9385011' 'Q82955' 'Q482980' 'Q162...
# 2                     NaN                                      ['Q14089670']
# 3                     NaN                                                NaN
# 4  ['Q678551' 'Q2505231']  ['Q33999' 'Q36180' 'Q28389' 'Q578109' 'Q245068...
# 5                     NaN                                        ['Q639669']
# 6                     NaN                   ['Q82955' 'Q1622272' 'Q1238570']
# 7                     NaN                                      ['Q11338576']
# 8                     NaN                                        ['Q488205']
# 9                     NaN                                      ['Q19204627']
#
#     Unnamed: 7        ['Q23635']  ['+1961-05-22T00:00:00Z']
# 0          NaN               NaN                        NaN
# 1  ['Q913404']           ['Q30']  ['+1951-09-18T00:00:00Z']
# 2          NaN          ['Q258']  ['+1998-01-23T00:00:00Z']
# 3          NaN          ['Q801']  ['+1946-01-03T00:00:00Z']
# 4          NaN           ['Q30']  ['+1981-06-01T00:00:00Z']
# 5          NaN           ['Q30']  ['+1961-08-08T00:00:00Z']
# 6          NaN           ['Q30']  ['+1952-12-23T00:00:00Z']
# 7          NaN               NaN  ['+1964-11-10T00:00:00Z']
# 8          NaN  ['Q1030' 'Q258']  ['+1982-00-00T00:00:00Z']
# 9          NaN           ['Q30']  ['+1948-09-10T00:00:00Z']

# %%
df.columns = ['id','quids', 'quoteID', 'gender', 'quote','ethnic_group','occupation','academic_degree','nationality','date_of_birth']

# %%
#women = df
women = df.drop(df[df['gender'] != 'female'].index)

# %%
women.head()
# Out:
#     id      quids            quoteID  gender  \
# 4    5   Q4749380  2020-04-01-000532  female
# 8    9   Q7322163  2020-03-23-000896  female
# 15  16    Q230744  2020-01-11-002445  female
# 16  17   Q7493177  2020-01-23-005418  female
# 19  20  Q43394564  2020-02-13-007205  female
#
#                                                 quote            ethnic_group  \
# 4   7pm is when most hospitals change shifts. That...  ['Q678551' 'Q2505231']
# 8   A little over a week old. Thankful for God's g...                     NaN
# 15  And help he always did. For someone who prefer...   ['Q42406' 'Q1344183']
# 16  And I think we've come to a time where we are ...              ['Q49085']
# 19  Apple prices generally peak in January. Betwee...                     NaN
#
#                                            occupation academic_degree  \
# 4   ['Q33999' 'Q36180' 'Q28389' 'Q578109' 'Q245068...             NaN
# 8                                         ['Q488205']             NaN
# 15        ['Q1930187' 'Q5436767' 'Q36180' 'Q1607826']             NaN
# 16                                         ['Q82955']             NaN
# 19                                                NaN             NaN
#
#          nationality              date_of_birth
# 4            ['Q30']  ['+1981-06-01T00:00:00Z']
# 8   ['Q1030' 'Q258']  ['+1982-00-00T00:00:00Z']
# 15          ['Q145']  ['+1949-11-03T00:00:00Z']
# 16           ['Q30']  ['+1952-07-14T00:00:00Z']
# 19               NaN                        NaN

# %%
nlp = spacy.load('en_core_web_sm')

all_quotes = women.drop(['id','quids','quoteID','gender','ethnic_group','occupation','academic_degree','nationality','date_of_birth'], axis = 1)
all_quotes.head()
# Out:
#                                                 quote
# 4   7pm is when most hospitals change shifts. That...
# 8   A little over a week old. Thankful for God's g...
# 15  And help he always did. For someone who prefer...
# 16  And I think we've come to a time where we are ...
# 19  Apple prices generally peak in January. Betwee...

# %%
open('c:/data/w/women.txt', 'w').close()
all_quotes.to_csv(r'c:/data/w/women.txt', header=None, index=None, sep=' ', mode='a')

# %%
path = "c:/data/w/"

with codecs.open(os.path.join(path,'women.txt'),encoding="utf8") as f:
    pack=f.read()
    f.close()
    
print(pack[0:600])
# Out:
# "7pm is when most hospitals change shifts. That's why. We love you heroes."
# "A little over a week old. Thankful for God's goodness."
# "And help he always did. For someone who preferred to be behind the scenes, he was at the center of absolutely everything."
# "And I think we've come to a time where we are prepared if women are not supported, then women are not going to continue to blindly support men who will not step up and take some leadership on this issue,"
# "Apple prices generally peak in January. Between December 2019 and January 2020, apple prices rose 22 percent to a weighted average p

# %%
from nltk.corpus import PlaintextCorpusReader
# ?PlaintextCorpusReader
place = PlaintextCorpusReader(path, '.*.txt')
print(place.fileids())
# Out:
# ['women.txt']

# %%
def get_chunks(l, n):
    """Yield successive n-sized chunks from l."""
    for i in range(0, len(l), n):
        yield l[i:i + n]


book_id = {f:n for n,f in enumerate(place.fileids())}
chunks = list()
chunk_class = list() # this list contains the original book of the chunk, for evaluation

limit = 500 # how many chunks total
size = 50 # how many sentences per chunk/page

for f in place.fileids():
    sentences = place.sents(f)
    print(f)
    
    # create chunks
    chunks_of_sents = [x for x in get_chunks(sentences,size)] # this is a list of lists of sentences, which are a list of tokens
    chs = list()
    
    # regroup so to have a list of chunks which are strings
    for c in chunks_of_sents:
        grouped_chunk = list()
        for s in c:
            grouped_chunk.extend(s)
        chs.append(" ".join(grouped_chunk))
    #print("Number of chunks:",len(chs),'\n')
    
    # filter to the limit, to have the same number of chunks per book
    chunks.extend(chs[:limit])
    chunk_class.extend([book_id[f] for _ in range(len(chs[:limit]))])
# Out:
# women.txt

# %%
STOPWORDS = spacy.lang.en.stop_words.STOP_WORDS

processed_docs = list()
for doc in nlp.pipe(chunks, batch_size=10):

    # Process document using Spacy NLP pipeline.
    ents = doc.ents  # Named entities

    # Keep only words (no numbers, no punctuation).
    # Lemmatize tokens, remove punctuation and remove stopwords.
    doc = [token.lemma_ for token in doc if token.is_alpha and not token.is_stop]

    # Remove common words from a stopword list and keep only words of length 3 or more.
    doc = [token for token in doc if token not in STOPWORDS and len(token) > 2]

    # Add named entities, but only if they are a compound of more than word.
    doc.extend([str(entity) for entity in ents if len(entity) > 1])

    processed_docs.append(doc)
docs = processed_docs
del processed_docs

# %%
# Add bigrams too
from gensim.models.phrases import Phrases

# Add bigrams to docs (only ones that appear 15 times or more).
bigram = Phrases(docs, min_count=15)

for idx in range(len(docs)):
    for token in bigram[docs[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            docs[idx].append(token)

# %%
# Create a dictionary representation of the documents, and filter out frequent and rare words.
from gensim.corpora import Dictionary
dictionary = Dictionary(docs)

# Remove rare and common tokens.
# Filter out words that occur too frequently or too rarely.
max_freq = 0.5
min_wordcount = 5
dictionary.filter_extremes(no_below=min_wordcount, no_above=max_freq)

# Bag-of-words representation of the documents.
corpus = [dictionary.doc2bow(doc) for doc in docs]
#MmCorpus.serialize("models/corpus.mm", corpus)

print('Number of unique tokens: %d' % len(dictionary))
print('Number of chunks: %d' % len(corpus))
# Out:
# Number of unique tokens: 5433
# Number of chunks: 500

# %%
# models
from gensim.models import LdaMulticore
params = {'passes': 10, 'random_state': seed}
base_models = dict()
model = LdaMulticore(corpus=corpus, num_topics=4, id2word=dictionary, workers=6,
                passes=params['passes'], random_state=params['random_state'])

# %%
model.show_topics(num_words=5)
# Out:
# [(0,
#   '0.003*"story" + 0.003*"face" + 0.002*"win" + 0.002*"hear" + 0.002*"game"'),
#  (1,
#   '0.003*"school" + 0.002*"use" + 0.002*"create" + 0.002*"issue" + 0.002*"ensure"'),
#  (2,
#   '0.003*"ensure" + 0.003*"understand" + 0.002*"risk" + 0.002*"story" + 0.002*"face"'),
#  (3,
#   '0.003*"school" + 0.003*"local" + 0.003*"believe" + 0.003*"protect" + 0.002*"issue"')]

# %%
NB_WORDS = 10

topic0 = model.show_topic(0,NB_WORDS)
topic1 = model.show_topic(1,NB_WORDS)
topic2 = model.show_topic(2,NB_WORDS)
topic3 = model.show_topic(3,NB_WORDS)

t0 = pd.DataFrame(topic0, columns = ['words','score'])
t1 = pd.DataFrame(topic1, columns = ['words','score'])
t2 = pd.DataFrame(topic2, columns = ['words','score'])
t3 = pd.DataFrame(topic3, columns = ['words','score'])
t0
# Out:
#     words     score
# 0   story  0.002683
# 1    face  0.002504
# 2     win  0.002358
# 3    hear  0.002337
# 4    game  0.002308
# 5  friend  0.002216
# 6  person  0.002200
# 7    film  0.002187
# 8   leave  0.002175
# 9   fight  0.002092

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, axes = plt.subplots(2, 2, figsize=(10,8))

sns.color_palette("deep")

#for col in ['t0','t1','t2','t3']

sns.barplot(x="score", y="words", data=t0, ax=axes[0,0], color='#d01c8b').set(title='First Topic')
sns.barplot(x="score", y="words", data=t1, ax=axes[0,1], color='#f1b6da').set(title='Second Topic')
sns.barplot(x="score", y="words", data=t2, ax=axes[1,0], color='#b8e186').set(title='Third Topic')
sns.barplot(x="score", y="words", data=t3, ax=axes[1,1], color='#4dac26').set(title='Fourth Topic')

f.suptitle('Topics in women\'s speeches in 2020')
plt.tight_layout();
plt.savefig("topics_2020");

# %%
#run with a bigger NB_WORDS
t0.append(t1).append(t2).append(t3).to_csv("all_2020_topics")

# %%
years = [2015, 2016, 2017, 2018,  2019, 2020]
interesting_words = ['school', 'student','kid', 'man', 'girl', 'health', 'care', 'film']
word = pd.DataFrame(columns = ['years'] + interesting_words)
word['years'] = years


for w in interesting_words:
    a = 0
    for i in years:
        topics_temp = pd.read_csv(f"{i}_topics")
        word[w].iloc[a] = topics_temp[topics_temp['words'] == w]['score'].sum() 
        a = a + 1
    plt.plot(years,word[w])
    plt.legend(interesting_words)
word
#plt.savefig("trend_individual_words")
# Out:
#    years    school   student       kid       man      girl    health  \
# 0   2015       0.0  0.008307  0.007668   0.00745       0.0   0.00753
# 1   2016  0.007243  0.007008  0.007858  0.007469  0.007586  0.006927
# 2   2017       0.0  0.007496  0.007988  0.008126  0.008865  0.007934
# 3   2018   0.00996  0.006802  0.007591  0.007867  0.007631  0.007538
# 4   2019  0.007973  0.006834  0.006925  0.007489  0.006933       0.0
# 5   2020  0.009553  0.006682   0.00637  0.006468  0.005767       0.0
#
#        care      film
# 0  0.007872  0.005771
# 1   0.00767  0.006198
# 2       0.0  0.006959
# 3  0.007902  0.007893
# 4  0.008752  0.008451
# 5       0.0   0.00639

# %% [markdown]
# ##### Empath

# %%
from empath import Empath
lexicon = Empath()

# %%
nlp = spacy.load('en_core_web_sm')

# %%
empath_features = lexicon.analyze(doc.text,categories = ["domestic_work","children", "aggression", "crime", "sexual","independence", "feminine","body", "violence","shame"], normalize = True)

# %%
empath_features.values()
# Out:
# dict_values([0.0019608180395259637, 0.004856178010171027, 0.001507880539167627, 0.001697082279823641, 0.0009460087032800702, 0.0011237436717751136, 0.0014734802226847154, 0.0026889580717475935, 0.003434298262210679, 0.0023220213625965358])

# %%
data = pd.DataFrame()
data['word'] = empath_features
data['score'] = empath_features.values()
data
# Out:
#                         word     score
# domestic_work  domestic_work  0.001961
# children            children  0.004856
# aggression        aggression  0.001508
# crime                  crime  0.001697
# sexual                sexual  0.000946
# independence    independence  0.001124
# feminine            feminine  0.001473
# body                    body  0.002689
# violence            violence  0.003434
# shame                  shame  0.002322

# %%
data = pd.DataFrame()
data['word'] = empath_features

for i in years:
    path = "c:/data/w/"
    
    df = pd.read_csv(f"fin_{i}.csv")
    
    df.columns = ['id','quids', 'quoteID', 'gender', 'quote','ethnic_group','occupation','academic_degree','nationality','date_of_birth']
    
    women = df.drop(df[df['gender'] != 'female'].index) 
    
    all_quotes = women.drop(['id','quids','quoteID','gender','ethnic_group','occupation','academic_degree','nationality','date_of_birth'], axis = 1)
    all_quotes.head()
    
    open('c:/data/w/women.txt', 'w').close()
    all_quotes.to_csv(r'c:/data/w/women.txt', header=None, index=None, sep=' ', mode='a')
    
    with codecs.open(os.path.join(path,'women.txt'),encoding="utf8") as f:
        pack=f.read()
        f.close()
        
    doc = nlp(pack[0:100000])
    
    empath_features = lexicon.analyze(doc.text,categories = ["domestic_work","children", "aggression", "crime", "sexual","independence", "feminine","body", "violence","shame"], normalize = True)
    
    
    data[i] = empath_features.values()

data
# Out:
#                         word      2015      2016      2017      2018  \
# domestic_work  domestic_work  0.001766  0.002265  0.001607  0.001761
# children            children  0.005525  0.005266  0.004478  0.005794
# aggression        aggression  0.001994  0.001755  0.001780  0.001591
# crime                  crime  0.001937  0.001189  0.001550  0.001477
# sexual                sexual  0.000740  0.000906  0.001435  0.001534
# independence    independence  0.000684  0.000906  0.000976  0.001193
# feminine            feminine  0.002221  0.001246  0.002182  0.001818
# body                    body  0.002848  0.002378  0.002067  0.002329
# violence            violence  0.002791  0.003850  0.004191  0.003522
# shame                  shame  0.002734  0.002604  0.002354  0.002613
#
#                    2019      2020
# domestic_work  0.001480  0.001662
# children       0.005351  0.004528
# aggression     0.001935  0.001089
# crime          0.001537  0.001834
# sexual         0.000683  0.000860
# independence   0.000740  0.001204
# feminine       0.001309  0.001433
# body           0.003302  0.002751
# violence       0.003871  0.003840
# shame          0.002960  0.002235

# %%
words = data['word']
data = data.drop(['word'], axis = 1)

# %%
plt.stackplot(years,data)
plt.legend(words);
plt.savefig("feminism_evolution")

# %% [markdown]
# ##### Count of words appearance

# %%
feminism = all_quotes['quote'].str.contains("feminism", case=True, flags=0, na=None, regex=True).sum()
feminism
# Out:
# 23

# %% [markdown]
# ## Age, ethnicity, occupation, academic degree, nationality

# %%
id_description = pd.read_csv('C:\data\wikidata_labels_descriptions.csv.bz2',compression='bz2')

#remove the [''] for the QIDS in the dff table
df_processed['ethnic_group']=df_processed['ethnic_group'].replace('\[', '',regex=True).replace('\'', '',regex=True).replace('\]', '',regex=True).replace('\'', '',regex=True)
df_processed['occupation']=df_processed['occupation'].replace('\[', '',regex=True).replace('\'', '',regex=True).replace('\]', '',regex=True).replace('\'', '',regex=True)
df_processed['academic_degree']=df_processed['academic_degree'].replace('\[', '',regex=True).replace('\'', '',regex=True).replace('\]', '',regex=True).replace('\'', '',regex=True)
df_processed['nationality']=df_processed['nationality'].replace('\[', '',regex=True).replace('\'', '',regex=True).replace('\]', '',regex=True).replace('\'', '',regex=True)

#replace the QIDS by their labels in the dff table
df_processed['ethnic_group'] = df_processed['ethnic_group'].map(id_description.set_index('QID')['Label'])
df_processed['occupation'] = df_processed['occupation'].map(id_description.set_index('QID')['Label'])
df_processed['academic_degree'] = df_processed['academic_degree'].map(id_description.set_index('QID')['Label'])
df_processed['nationality'] = df_processed['nationality'].map(id_description.set_index('QID')['Label'])

df_processed.to_csv("table_with_label")

#This cell was not run again because it was run on a different notebook since the work was split 
#between the team members. It took a lot of time to run already on the other notebook so we could not 
#run it again here.

# %%
df_label=pd.read_csv('C:/data/table_with_label.csv')

# %%
df_label['year_of_birth'] = df_label['date_of_birth'].str[3:7]

# %%
def gender(x):
    
    'Function to convert wikidata id into a gender string value'
    'We consider male and female as male/female and transgender male/female respectly'

    if x == "['Q6581097']" or x =="['Q2449503']": #males and transgender males
        return 'male'
    elif x == "['Q6581072']" or  x ==  "['Q1052281']": #females and transgender females
        return 'female'
    elif pd.isna(x):
        return np.nan
    else:
        return 'other'

df_label['gen'] = df_label['gender'].apply(gender)
df_label['gen'].value_counts(dropna=False)
# Out:
# male      575884
# female    111597
# NaN        13523
# other        510
# Name: gen, dtype: int64

# %%
df_label.head()
# Out:
#    Unnamed: 0            quoteID  \
# 0           0  2020-01-17-000357
# 1           1  2020-04-02-000239
# 2           2  2020-03-19-000276
# 3           3  2020-01-08-000594
# 4           4  2020-02-21-000455
#
#                                            quotation          speaker  \
# 0  [ The delay ] will have an impact [ on Slough ...     Dexter Smith
# 1  [ The scheme ] treats addiction as an illness ...  Barry Coppinger
# 2  [ These ] actions will allow households who ha...       Ben Carson
# 3                   11 straight weeks of pre-season,   Aphelele Fassi
# 4  2019 was a landmark year for Fiverr as we comp...    Micha Kaufman
#
#         qids                 date  numOccurrences  \
# 0   Q5268447  2020-01-17 13:03:00               1
# 1   Q4864119  2020-04-02 14:18:20               1
# 2    Q816459  2020-03-19 19:14:00               1
# 3  Q56255401  2020-01-08 10:22:11               1
# 4  Q26923564  2020-02-21 13:00:00               1
#
#                                               probas  \
# 0     [['Dexter Smith', '0.924'], ['None', '0.076']]
# 1  [['Barry Coppinger', '0.9017'], ['None', '0.09...
# 2     [['Ben Carson', '0.9227'], ['None', '0.0773']]
# 3  [['Aphelele Fassi', '0.9033'], ['None', '0.096...
# 4  [['Micha Kaufman', '0.9409'], ['None', '0.0591']]
#
#                                                 urls phase         number  \
# 0  ['http://www.sloughexpress.co.uk/gallery/sloug...     E    0.924 0.076
# 1  ['http://www.theweek.co.uk/106479/why-police-a...     E  0.9017 0.0983
# 2  ['https://mortgageorb.com/hud-fha-suspend-fore...     E  0.9227 0.0773
# 3  ['https://www.sport24.co.za/Rugby/SuperRugby/s...     E  0.9033 0.0967
# 4  ['https://www.fool.com/investing/2020/02/21/wh...     E  0.9409 0.0591
#
#          gender       ethnic_group          occupation     academic_degree  \
# 0  ['Q6581097']                NaN           cricketer                 NaN
# 1  ['Q6581097']                NaN                 NaN                 NaN
# 2  ['Q6581097']  African Americans                 NaN  Doctor of Medicine
# 3  ['Q6581097']                NaN  rugby union player                 NaN
# 4  ['Q6581097']                NaN                 NaN                 NaN
#
#                 nationality              date_of_birth year_of_birth   gen
# 0                   Bermuda  ['+1961-05-22T00:00:00Z']          1961  male
# 1                       NaN                        NaN           NaN  male
# 2  United States of America  ['+1951-09-18T00:00:00Z']          1951  male
# 3              South Africa  ['+1998-01-23T00:00:00Z']          1998  male
# 4                    Israel  ['+1946-01-03T00:00:00Z']          1946  male

# %%
df_label['year_of_birth']=df_label['year_of_birth'].astype(float)
df_women = df_label[df_label['gen']=='female']
df_men = df_label[df_label['gen']=='male']

# %%
everyone=plt.hist(data=df_label, x="year_of_birth", label='All speakers',range=[1900,2020], bins=20, alpha=0.5);
women=plt.hist(data=df_women, x="year_of_birth",label='Only women',range=[1900,2020], bins=20, alpha=0.5);
plt.title('Distribution of speaker\'s year of birth');
plt.xlabel('Year of birth of the speakers');
plt.ylabel('Number of speakers');
plt.legend();

# %%
df_ethnic_men = df_men['ethnic_group'].value_counts().rename_axis('Ethnicity of men').reset_index(name='Counts men')
df_ethnic_women = df_women['ethnic_group'].value_counts().rename_axis('Ethnicity of women').reset_index(name='Counts women')
df_ethnic = pd.merge(df_ethnic_men,df_ethnic_women, left_index=True, right_index=True)
df_ethnic.head(10)
# Out:
#      Ethnicity of men  Counts men       Ethnicity of women  Counts women
# 0   African Americans       12272        African Americans          4281
# 1       Jewish people        4187         Italian American           727
# 2    Italian American        2480          White Americans           698
# 3       White British        1381                Armenians           477
# 4       American Jews         882                  Germans           372
# 5            Pashtuns         713               Bulgarians           351
# 6       Yoruba people         711          Irish Americans           281
# 7  Italian Argentines         694         Chinese American           216
# 8    Maltese American         634  Stateside Puerto Ricans           164
# 9               Turks         576                  Indians           147

# %%
df_occupation_men = df_men['occupation'].value_counts().rename_axis('Occupation of men').reset_index(name='Counts men')
df_occupation_women = df_women['occupation'].value_counts().rename_axis('Occupation of women').reset_index(name='Counts women')
df_occupation = pd.merge(df_occupation_men,df_occupation_women, left_index=True, right_index=True)
df_occupation.head(10)
# Out:
#                   Occupation of men  Counts men          Occupation of women  \
# 0                        politician       64894                   politician
# 1       association football player       28395                   researcher
# 2                         cricketer       13827                        actor
# 3          American football player       13366                   journalist
# 4                 ice hockey player       13071                    cricketer
# 5                        researcher       10554  association football player
# 6                 basketball player       10283                       singer
# 7                   baseball player        8576                       writer
# 8                    businessperson        6058                tennis player
# 9  Australian rules football player        5765               businessperson
#
#    Counts women
# 0         15859
# 1          4015
# 2          2038
# 3          1419
# 4          1246
# 5          1085
# 6           979
# 7           883
# 8           829
# 9           809
